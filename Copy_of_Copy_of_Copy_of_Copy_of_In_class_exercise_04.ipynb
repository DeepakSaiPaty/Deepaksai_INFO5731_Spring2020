# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepakSaiPaty/Deepaksai_INFO5731_Spring2020/blob/master/Copy_of_Copy_of_Copy_of_Copy_of_In_class_exercise_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fourth in-class-exercise**

# %% [markdown]
# # 1. Text Data Preprocessing
#
# Here is a [legal case](https://github.com/unt-iialab/INFO5731_Spring2020/blob/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# ## 1.1 Basic feature extraction using text data
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# ## 1.2 Basic Text Pre-processing of text data
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# ## 1.3 Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above.
#
#
# ## 1.4 Advance Text Processing
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 2-grams terms as features.

# %%
# Write your code here
pip install pysbd

# %%
pip install spacy

# %%
import spacy
import pysbd            #calculation of sentences
f = open("data.txt", "r")
data=f.read()
seg = pysbd.Segmenter(language="en", clean=False)
sentences=seg.segment(data)
print('Total Number of Sentences:',len(sentences))
# Out:
# Total Number of Sentences: 220

# %%
import string             #Removed Punctuation
import regex as re
import pandas as pd
noise_df=pd.DataFrame(sentences,columns=['Data'])
df= noise_df['Data'].apply(lambda x:''.join([i for i in x if i not in string.punctuation])).to_frame()
df2= df['Data'].map(lambda x: re.sub(r'\W+', ' ', x))
cleaned_list=df2.values.tolist()
(cleaned_list)
# Out:
# ['5 Ala 740',
#  'Supreme Court of Alabama',
#  'ADAMS',
#  'v',
#  'TANNER AND HORTON',
#  'June Term 1843',
#  'Synopsis',
#  'WRIT of Error to the Circuit Court of Sumter',
#  'West Headnotes 2',
#  '1',
#  'Chattel Mortgages',
#  'Crops',
#  'A growing crop has such an existence as to be the subjectmatter of a mortgage or other contract which passes an interest to vest in possession either immediately or at a future time',
#  '4 Cases that cite this headnote',
#  '2',
#  'Creditors Remedies',
#  'Lien and Priority',
#  'Under St1821 prohibiting a levy on a crop until it has been gathered no lien attaches in favor of a fi',
#  'fa',
#  'on a growing crop nor does such lien attach until after the crop has been gathered',
#  '5 Cases that cite this headnote',
#  '1 This was a trial of the right of property under the statute',
# ...

# %%
import re 
def remove(list):                   #Removed numbers from data and calculated words
    pattern = '[0-9]'
    list = [re.sub(pattern, '', i) for i in list] 
    return list
words=remove(cleaned_list)
number_of_words=[]
for i in words:
  res = len(re.findall(r'\w+',i)) 
  number_of_words.append(res)
print('Total Number of words:',sum(number_of_words))
print('Document for calculation of words-')
words
# Out:
# Total Number of words: 3540
# Document for calculation of words-
# [' Ala ',
#  'Supreme Court of Alabama',
#  'ADAMS',
#  'v',
#  'TANNER AND HORTON',
#  'June Term ',
#  'Synopsis',
#  'WRIT of Error to the Circuit Court of Sumter',
#  'West Headnotes ',
#  '',
#  'Chattel Mortgages',
#  'Crops',
#  'A growing crop has such an existence as to be the subjectmatter of a mortgage or other contract which passes an interest to vest in possession either immediately or at a future time',
#  ' Cases that cite this headnote',
#  '',
#  'Creditors Remedies',
#  'Lien and Priority',
#  'Under St prohibiting a levy on a crop until it has been gathered no lien attaches in favor of a fi',
#  'fa',
#  'on a growing crop nor does such lien attach until after the crop has been gathered',
#  ' Cases that cite this headnote',
#  ' This was a trial of the right of property under the statute',
# ...

# %%
no_space_cleaned= df['Data'].map(lambda x: re.sub(r'\W+', '', x))
no_space_l=no_space_cleaned.values.tolist()     #Removed spaces from data and calculated number of characters
chars_only=remove(no_space_l)
chars_only
def count_chars(txt):
	result = 0
	for char in txt:
		result += 1     
	return result
characters=[]
for i in chars_only:
  characters.append(count_chars(i))
print('Total number of words-',sum(characters))
print('Document for calculation of chars-')
chars_only
# Out:
# Total number of words- 15547
# Document for calculation of chars-
# ['Ala',
#  'SupremeCourtofAlabama',
#  'ADAMS',
#  'v',
#  'TANNERANDHORTON',
#  'JuneTerm',
#  'Synopsis',
#  'WRITofErrortotheCircuitCourtofSumter',
#  'WestHeadnotes',
#  '',
#  'ChattelMortgages',
#  'Crops',
#  'Agrowingcrophassuchanexistenceastobethesubjectmatterofamortgageorothercontractwhichpassesaninteresttovestinpossessioneitherimmediatelyoratafuturetime',
#  'Casesthatcitethisheadnote',
#  '',
#  'CreditorsRemedies',
#  'LienandPriority',
#  'UnderStprohibitingalevyonacropuntilithasbeengatherednolienattachesinfavorofafi',
#  'fa',
#  'onagrowingcropnordoessuchlienattachuntilafterthecrophasbeengathered',
#  'Casesthatcitethisheadnote',
#  'Thiswasatrialoftherightofpropertyunderthestatute',
#  'InNovemberanexecutionissuedfromthecircuitcourtofSumteratthesuitoftheplaintiffinerrorrequiringthesheriffofthatcountytomakeofthegoodsc',
# ...

# %%
average_l=[]      #Average word count
for j in words:
  try:
    w = j.split()
    average = sum(len(word) for word in w) / len(w)
    average_l.append(average)
  except:
    continue; #If there are no words
print('Average word count in document-',sum(average_l)/len(average_l))
# Out:
# Average word count in document- 4.552546510966314

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> all
# Command 'all' unrecognized
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
# ...

# %%
import nltk
from nltk.corpus import stopwords         #calculating stop words
from nltk.tokenize import word_tokenize
lower_words=[]
count=[]
for i in words:
  lower_words.append(i.lower())
  stop_words = set(stopwords.words('english')) 
  word_tokens = word_tokenize(i) 
  filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  filtered_sentence = [] 
  for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
  count.append(len(word_tokens)-len(filtered_sentence))
print('Total stop Words-',sum(count))
# Out:
# Total stop Words- 1732

# %%
sentences
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-99331a9e6469> in <module>()
# ----> 1 sentences
#
# NameError: name 'sentences' is not defined

# %% [markdown]
# # 2. Python Regular Expression

# %% [markdown]
# ## 2.1 Write a Python program to remove leading zeros from an IP address.
#
# ip = "260.08.094.109"

# %%
# Write your code here
import re
ip = "260.08.094.109"
output1 = re.sub(r'\b0+(\d)', r'\1', ip)
output1
# Out:
# '260.8.94.109'

# %% [markdown]
# ## 2.2 Write a Python Program to extract all the years from the following sentence.
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
# Write your code here
import re
sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."
output2=re.findall(r'2\d\d\d', sentence)
output2
# Out:
# ['2010', '2010', '2019']
