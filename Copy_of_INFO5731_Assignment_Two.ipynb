# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepakSaiPaty/Deepaksai_INFO5731_Spring2020/blob/master/Copy_of_INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#wuhancoronovirus"](https://twitter.com/hashtag/wuhancoronovirus) from Twitter.

# %%
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [36.9 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [818 kB]
# Get:15 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Get:16 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,765 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [11.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,104 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [7,064 B]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [27.5 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [817 kB]
# Get:22 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [83.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,345 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [41.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [4,252 B]
# Get:26 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [852 kB]
# Fetched 7,204 kB in 4s (1,760 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension adobe-flashplugin
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 91 not upgraded.
# Need to get 74.4 MB of archives.
# After this operation, 264 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 80.0.3987.87-0ubuntu0.18.04.1 [1,095 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 80.0.3987.87-0ubuntu0.18.04.1 [66.1 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 80.0.3987.87-0ubuntu0.18.04.1 [3,155 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 80.0.3987.87-0ubuntu0.18.04.1 [4,044 kB]
# Fetched 74.4 MB in 5s (14.8 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 134443 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_80.0.3987.87-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (80.0.3987.87-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_80.0.3987.87-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (80.0.3987.87-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_80.0.3987.87-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (80.0.3987.87-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_80.0.3987.87-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (80.0.3987.87-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (80.0.3987.87-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (80.0.3987.87-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (80.0.3987.87-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (80.0.3987.87-0ubuntu0.18.04.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Requirement already satisfied: selenium in /usr/local/lib/python3.6/dist-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium) (1.24.3)

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')
# browser.get("https://www.python.org/")
# nav = browser.find_element_by_id("mainnav")
# print(nav.text)

# %%
driver = webdriver.Chrome('chromedriver',options=options)
import pandas as pd
import time
reviews=[]
username=[]
date=[]
#titles_l=[]
driver.get('https://www.imdb.com/title/tt7286456/reviews?sort=helpfulnessScore&dir=desc&ratingFilter=10')
for i in range(3):
  button=driver.find_element_by_xpath('/html[1]/body[1]/div[3]/div[1]/div[2]/div[3]/div[1]/section[1]/div[2]/div[4]/div[1]/button[1]').click()
  time.sleep(3)
items=driver.find_elements_by_class_name("content")
for item in items:
  reviews.append(item.find_element_by_css_selector('.text.show-more__control').text)
users=driver.find_elements_by_class_name("display-name-date")
for user in users:
  username.append(user.find_element_by_tag_name('a').text)
  date.append(user.find_element_by_class_name('review-date').text)
titles=driver.find_elements_by_class_name("lister-item-content")
#for title in titles:
 # titles_l.append(title.find_element_by_tag_name('a').text)
reviews_df=pd.DataFrame(reviews, columns = ['Review'])
username_df=pd.DataFrame(username, columns = ['Username'])
date_df=pd.DataFrame(date, columns = ['Date'])
#titles_df=pd.DataFrame(titles_l, columns = ['Title'])
joker_data=pd.concat([date_df,username_df,reviews_df],axis=1)
joker_data.to_csv('output2.csv')
joker_data
# Out:
#                  Date  ...                                             Review
# 0   10 September 2019  ...  I was a person that saw all the hype and claim...
# 1      3 October 2019  ...  Every once in a while a movie comes, that trul...
# 2      7 October 2019  ...  This is a movie that only those who have felt ...
# 3    1 September 2019  ...  Truly a masterpiece, The Best film of 2019, on...
# 4      4 October 2019  ...  Most of the time movies are anticipated like t...
# ..                ...  ...                                                ...
# 95     6 October 2019  ...  I personally loved the film but, let's be hone...
# 96     4 October 2019  ...  Best Joker adaption ever, everything dark you'...
# 97     7 October 2019  ...
# 98   1 September 2019  ...  This movie is getting a lot of praise and this...
# 99   1 September 2019  ...  Phoenix is a best joker ever he deserved oscar...
#
# [100 rows x 3 columns]

# %% [markdown]
# **Here I am considering only review column for further processing...**

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
import regex as re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer 
import pandas as pd
df = reviews_df['Review'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE).to_frame()# 1.removed noise (special characters and punctuations)
df=df['Review'].str.replace('[^\w\s]','').replace('\n','', regex=True).to_frame()
no_nums=df['Review'].str.replace('\d+', '').to_frame()   # 2.Removed Numbers
lower = no_nums['Review'].str.lower().to_frame()  # 4.converted to lower case letters
stemmed=[]
lemmatized=[]
sentence=[]
stop_words = set(stopwords.words('english')) 
listed=lower['Review'].values.tolist()
for i in listed:
   word_tokens = word_tokenize(i) 
   filtered_sentence = [w for w in word_tokens if not w in stop_words] 
   filtered_sentence = []
   for w in word_tokens: 
     if w not in stop_words: 
         filtered_sentence.append(w)     # 3. Removed stop words
   sentence.append(' '.join(filtered_sentence))
ps = PorterStemmer() 
stemmed = []
for s in sentence:
    stemmed.append(" ".join([ps.stem(i) for i in s.split()]))       #5.Stemming
lemmatizer = WordNetLemmatizer() 
lemmatized=[]
for m in stemmed:
  lemmatized.append(" ".join([lemmatizer.lemmatize(i) for i in m.split()]))     #6.lemmatization
lemmatized_df=pd.DataFrame(lemmatized,columns=['Cleaned_data'])
#lemmatized_df.to_csv('Cleaned_data.csv')
df_csv = pd.read_csv('output2.csv')
# provided that their lengths match
df_csv['Cleaned_Review_column'] = lemmatized_df['Cleaned_data']
df_csv.to_csv('cleaned.csv')

# %% [markdown]
# **There are very few missing fields in data which represents spoilers.**

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
pos=[]
count=0
for i in lemmatized:
  text = word_tokenize(i)
  count=count+1
  pos.append(nltk.pos_tag(text))    #Parts of Speech for each sentence
pos
#len(pos)
# Out:
# [[('person', 'NN'),
#   ('saw', 'VBD'),
#   ('hype', 'JJ'),
#   ('claim', 'NN'),
#   ('masterpiec', 'NN'),
#   ('overreact', 'JJ'),
#   ('overblown', 'JJ'),
#   ('excit', 'NN'),
#   ('anoth', 'DT'),
#   ('joker', 'NN'),
#   ('base', 'NN'),
#   ('film', 'NN'),
#   ('thought', 'VBD'),
#   ('look', 'NN'),
#   ('solid', 'JJ'),
#   ('best', 'RB'),
#   ('even', 'RB'),
#   ('bit', 'VB'),
#   ('pretenti', 'JJ'),
#   ('trailer', 'NNS'),
#   ('say', 'VBP'),
#   ('incred', 'VBN'),
#   ('wrong', 'JJ'),
#   ('massiv', 'NN'),
#   ('achiev', 'NN'),
#   ('cinema', 'NN'),
#   ('that', 'WDT'),
#   ('extrem', 'VBZ'),
#   ('rare', 'JJ'),
#   ('day', 'NN'),
#   ('age', 'NN'),
#   ('cgi', 'NN'),
#   ('nonsens', 'NNS'),
#   ('reboot', 'VBP'),
#   ('somewhat', 'RB'),
#   ('reboot', 'JJ'),
#   ('sort', 'NN'),
#   ('standalon', 'NN'),
#   ('origin', 'NN'),
#   ('tale', 'NN'),
#   ('impecc', 'JJ'),
#   ('start', 'JJ'),
#   ('finish', 'NN'),
#   ('echo', 'NN'),
#   ('resembl', 'NN'),
#   ('best', 'JJS'),
#   ('joker', 'NN'),
#   ('origin', 'NN'),
#   ('comic', 'JJ'),
#   ('past', 'NN'),
#   ('joaquin', 'NN'),
#   ('bleed', 'NN'),
#   ('sweat', 'NN'),
#   ('cri', 'NN'),
#   ('everi', 'VBP'),
#   ('drop', 'NN'),
#   ('magnific', 'NN'),
#   ('dedic', 'JJ'),
#   ('perform', 'NN'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('would', 'MD'),
#   ('proud', 'VB'),
#   ('undoubtedli', 'JJ'),
#   ('greatest', 'JJS'),
#   ('act', 'NN'),
#   ('perform', 'NN'),
#   ('sinc', 'JJ'),
#   ('heath', 'NN'),
#   ('joker', 'NN'),
#   ('direct', 'JJ'),
#   ('write', 'NN'),
#   ('slickli', 'NN'),
#   ('brilliant', 'JJ'),
#   ('bleak', 'NN'),
#   ('set', 'VBN'),
#   ('tone', 'NN'),
#   ('palpabl', 'NN'),
#   ('throughout', 'IN'),
#   ('film', 'NN'),
#   ('place', 'NN'),
#   ('blown', 'VBN'),
#   ('away', 'RB'),
#   ('everi', 'JJ'),
#   ('audienc', 'JJ'),
#   ('member', 'NN'),
#   ('awestruck', 'NN'),
#   ('wit', 'NN'),
#   ('film', 'NN'),
#   ('could', 'MD'),
#   ('still', 'RB'),
#   ('transport', 'VB'),
#   ('charact', 'JJ'),
#   ('world', 'NN'),
#   ('exist', 'VBP'),
#   ('believ', 'NN'),
#   ('hype', 'NN'),
#   ('go', 'VBP'),
#   ('rever', 'RB'),
#   ('transcend', 'VBP'),
#   ('masterpiec', 'NNS'),
#   ('cinema', 'NN')],
#  [('everi', 'RB'),
#   ('movi', 'JJ'),
#   ('come', 'VBP'),
#   ('truli', 'NNS'),
#   ('make', 'VBP'),
#   ('impact', 'JJ'),
#   ('joaquin', 'NN'),
#   ('perform', 'NN'),
#   ('scenographi', 'NN'),
#   ('brillianc', 'NN'),
#   ('grotesqu', 'NN'),
#   ('haunt', 'NN'),
#   ('cringi', 'JJ'),
#   ('hard', 'JJ'),
#   ('watch', 'NN'),
#   ('time', 'NN'),
#   ('mesmer', 'JJ'),
#   ('wont', 'NN'),
#   ('blink', 'NN'),
#   ('eye', 'NN'),
#   ('watch', 'NN'),
#   ('tragic', 'VBP'),
#   ('serious', 'JJ'),
#   ('funni', 'JJ'),
#   ('moment', 'NN'),
#   ('emot', 'NN'),
#   ('rollercoast', 'NN'),
#   ('sometim', 'NN'),
#   ('multipl', 'NN'),
#   ('emot', 'NN'),
#   ('poppingup', 'NN'),
#   ('timethi', 'NN'),
#   ('far', 'RB'),
#   ('typic', 'JJ'),
#   ('actionriddl', 'JJ'),
#   ('predict', 'NN'),
#   ('superhero', 'NN'),
#   ('movi', 'NN'),
#   ('proper', 'IN'),
#   ('psycholog', 'NN'),
#   ('thrillerdrama', 'NN'),
#   ('singl', 'NN'),
#   ('best', 'JJS'),
#   ('charact', 'NN'),
#   ('develop', 'VB'),
#   ('ever', 'RB'),
#   ('seen', 'VBN')],
#  [('movi', 'NN'),
#   ('felt', 'VBD'),
#   ('alon', 'JJ'),
#   ('isol', 'NN'),
#   ('truli', 'NN'),
#   ('relat', 'JJ'),
#   ('understand', 'NN'),
#   ('motiv', 'NN'),
#   ('feel', 'NN'),
#   ('sorri', 'JJ'),
#   ('charact', 'NN'),
#   ('lot', 'NN'),
#   ('peopl', 'IN'),
#   ('see', 'VBP'),
#   ('movi', 'JJ'),
#   ('think', 'VBP'),
#   ('encourag', 'JJ'),
#   ('violenc', 'NN'),
#   ('truli', 'NN'),
#   ('movi', 'NN'),
#   ('encourag', 'VBP'),
#   ('everi', 'IN'),
#   ('one', 'CD'),
#   ('u', 'NN'),
#   ('becom', 'NN'),
#   ('better', 'RBR'),
#   ('person', 'NN'),
#   ('treat', 'JJ'),
#   ('everyon', 'NN'),
#   ('respect', 'NN'),
#   ('make', 'VBP'),
#   ('feel', 'NN'),
#   ('like', 'IN'),
#   ('belong', 'JJ'),
#   ('world', 'NN'),
#   ('instead', 'RB'),
#   ('make', 'VB'),
#   ('feel', 'NN'),
#   ('isol', 'NN')],
#  [('truli', 'NNS'),
#   ('masterpiec', 'VBP'),
#   ('best', 'JJS'),
#   ('film', 'NN'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('film', 'NN'),
#   ('decad', 'NN'),
#   ('truli', 'NN'),
#   ('best', 'JJS'),
#   ('film', 'NN'),
#   ('bring', 'VBG'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('chillingli', 'NN'),
#   ('realist', 'NN'),
#   ('real', 'JJ'),
#   ('ife', 'JJ'),
#   ('remark', 'NN'),
#   ('direct', 'JJ'),
#   ('cinematographi', 'NN'),
#   ('music', 'NN'),
#   ('act', 'NN'),
#   ('dont', 'JJ'),
#   ('understand', 'JJ'),
#   ('critic', 'JJ'),
#   ('surpris', 'NN'),
#   ('find', 'VBP'),
#   ('disturb', 'JJ'),
#   ('violent', 'NN'),
#   ('titl', 'NN'),
#   ('charact', 'NN'),
#   ('infam', 'JJ'),
#   ('fan', 'NN'),
#   ('alreadi', 'JJ'),
#   ('root', 'NN'),
#   ('oscar', 'NN'),
#   ('way', 'NN')],
#  [('time', 'NN'),
#   ('movi', 'JJ'),
#   ('anticip', 'NNS'),
#   ('like', 'IN'),
#   ('end', 'VBP'),
#   ('fall', 'NN'),
#   ('short', 'JJ'),
#   ('way', 'NN'),
#   ('short', 'JJ'),
#   ('joker', 'NN'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('happi', 'NN'),
#   ('hype', 'NN'),
#   ('plea', 'NN'),
#   ('ignor', 'JJ'),
#   ('complaint', 'NN'),
#   ('pernici', 'NN'),
#   ('violenc', 'JJ'),
#   ('embarrass', 'NNS'),
#   ('say', 'VBP'),
#   ('least', 'JJS'),
#   ('havent', 'JJ'),
#   ('seen', 'VBN'),
#   ('comic', 'JJ'),
#   ('movi', 'NN'),
#   ('real', 'JJ'),
#   ('ever', 'RB'),
#   ('deserv', 'VBP'),
#   ('better', 'JJR'),
#   ('class', 'NN'),
#   ('crimin', 'NN'),
#   ('phillip', 'NN'),
#   ('phoenix', 'NN'),
#   ('deliv', 'NN'),
#   ('dark', 'NN'),
#   ('joker', 'NN'),
#   ('dark', 'JJ'),
#   ('fall', 'NN'),
#   ('love', 'NN'),
#   ('villain', 'NN'),
#   ('bad', 'JJ'),
#   ('guy', 'NN'),
#   ('alway', 'NN'),
#   ('romant', 'JJ'),
#   ('anyway', 'NN')],
#  [('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('give', 'VB'),
#   ('tour', 'NN'),
#   ('de', 'IN'),
#   ('forc', 'FW'),
#   ('perform', 'NN'),
#   ('fearless', 'NN'),
#   ('stun', 'NN'),
#   ('emot', 'NN'),
#   ('depth', 'NN'),
#   ('physic', 'JJ'),
#   ('imposs', 'NN'),
#   ('talk', 'NN'),
#   ('without', 'IN'),
#   ('referenc', 'JJ'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('oscarwin', 'VBP'),
#   ('perform', 'NN'),
#   ('dark', 'NN'),
#   ('knight', 'VBD'),
#   ('wide', 'JJ'),
#   ('consid', 'NN'),
#   ('definit', 'NN'),
#   ('liveact', 'JJ'),
#   ('portray', 'NN'),
#   ('joker', 'NN'),
#   ('let', 'VBD'),
#   ('talk', 'VB'),
#   ('fact', 'NN'),
#   ('everyon', 'RB'),
#   ('go', 'VB'),
#   ('stun', 'JJ'),
#   ('phoenix', 'NN'),
#   ('accomplish', 'JJ'),
#   ('mani', 'NN'),
#   ('thought', 'VBD'),
#   ('imposs', 'IN'),
#   ('portray', 'JJ'),
#   ('match', 'NN'),
#   ('potenti', 'NN'),
#   ('exce', 'NN'),
#   ('dark', 'NN'),
#   ('knight', 'VBD'),
#   ('clown', 'JJ'),
#   ('princ', 'NN'),
#   ('crime', 'NN')],
#  [('let', 'VB'),
#   ('start', 'VB'),
#   ('say', 'VB'),
#   ('joaquin', 'JJ'),
#   ('phoneix', 'NN'),
#   ('doesnt', 'NN'),
#   ('get', 'NN'),
#   ('oscar', 'NN'),
#   ('movi', 'NN'),
#   ('oscar', 'NN'),
#   ('cancel', 'NN'),
#   ('phoneix', 'NN'),
#   ('amaz', 'NN'),
#   ('mightv', 'FW'),
#   ('heard', 'NN'),
#   ('everi', 'NN'),
#   ('review', 'NN'),
#   ('ever', 'RB'),
#   ('todd', 'JJ'),
#   ('phillip', 'NN'),
#   ('best', 'JJS'),
#   ('stori', 'JJ'),
#   ('line', 'NN'),
#   ('take', 'VB'),
#   ('visual', 'JJ'),
#   ('breathtak', 'NN'),
#   ('score', 'NN'),
#   ('omg', 'NN'),
#   ('score', 'NN'),
#   ('everi', 'JJ'),
#   ('time', 'NN'),
#   ('score', 'NN'),
#   ('came', 'VBD'),
#   ('felt', 'VBD'),
#   ('uncomfort', 'JJ'),
#   ('like', 'IN'),
#   ('someth', 'JJ'),
#   ('horribl', 'NN'),
#   ('happen', 'VB'),
#   ('great', 'JJ'),
#   ('inspir', 'JJ'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('king', 'VBG'),
#   ('comedi', 'NN'),
#   ('add', 'RB'),
#   ('much', 'JJ'),
#   ('movi', 'NN'),
#   ('got', 'VBD'),
#   ('honest', 'JJ'),
#   ('scene', 'NN'),
#   ('violent', 'NN'),
#   ('disturb', 'NN'),
#   ('honestli', 'NN'),
#   ('expect', 'VBP'),
#   ('wayyyi', 'JJ'),
#   ('violent', 'JJ'),
#   ('controversi', 'NN'),
#   ('go', 'VBP'),
#   ('overal', 'JJ'),
#   ('movi', 'RB'),
#   ('great', 'JJ'),
#   ('come', 'JJ'),
#   ('oscar', 'NN'),
#   ('season', 'NN'),
#   ('need', 'VBP'),
#   ('nomin', 'RB'),
#   ('best', 'RBS'),
#   ('pictur', 'JJ'),
#   ('screenplay', 'NN'),
#   ('cinematographi', 'NN'),
#   ('actor', 'NN'),
#   ('score', 'NN'),
#   ('director', 'NN')],
#  [('get', 'VB'),
#   ('peopl', 'JJ'),
#   ('hate', 'NN'),
#   ('polit', 'NN'),
#   ('messag', 'NN'),
#   ('peopl', 'NN'),
#   ('think', 'VBP'),
#   ('need', 'MD'),
#   ('get', 'VB'),
#   ('empathi', 'VB'),
#   ('arthur', 'JJ'),
#   ('mad', 'JJ'),
#   ('come', 'VBN'),
#   ('point', 'NN'),
#   ('never', 'RB'),
#   ('enjoy', 'VB'),
#   ('masterpiec', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('todd', 'NN'),
#   ('phillip', 'NN'),
#   ('overdid', 'JJ'),
#   ('movi', 'NN'),
#   ('actingmus', 'NN'),
#   ('cinematographi', 'NN'),
#   ('amaz', 'VBP'),
#   ('plea', 'NN'),
#   ('enjoy', 'NN'),
#   ('movi', 'NN'),
#   ('without', 'IN'),
#   ('overthink', 'NN')],
#  [('seen', 'VBN'),
#   ('joker', 'NN'),
#   ('yesterday', 'NN'),
#   ('venic', 'JJ'),
#   ('earli', 'NN'),
#   ('illfat', 'NN'),
#   ('screen', 'NN'),
#   ('troubl', 'NN'),
#   ('audio', 'JJ'),
#   ('lead', 'NN'),
#   ('nearhour', 'JJ'),
#   ('delay', 'NN'),
#   ('definit', 'NN'),
#   ('worth', 'JJ'),
#   ('itjok', 'NN'),
#   ('deserv', 'NN'),
#   ('present', 'JJ'),
#   ('venic', 'JJ'),
#   ('film', 'NN'),
#   ('festiv', 'JJ'),
#   ('event', 'NN'),
#   ('regard', 'NN'),
#   ('cinema', 'NN'),
#   ('form', 'NN'),
#   ('art', 'NN'),
#   ('film', 'NN'),
#   ('far', 'RB'),
#   ('blockbust', 'RB'),
#   ('mere', 'JJ'),
#   ('entertain', 'VBP'),
#   ('movi', 'JJ'),
#   ('film', 'NN'),
#   ('genr', 'NN'),
#   ('areit', 'IN'),
#   ('focus', 'NN'),
#   ('psych', 'NN'),
#   ('main', 'JJ'),
#   ('charact', 'NN'),
#   ('slowli', 'NN'),
#   ('crumbl', 'NN'),
#   ('pressur', 'NN'),
#   ('societi', 'NN'),
#   ('thu', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('wonder', 'VBP'),
#   ('perform', 'NN'),
#   ('earn', 'VBP'),
#   ('almost', 'RB'),
#   ('sure', 'JJ'),
#   ('nomin', 'JJ'),
#   ('oscar', 'NN'),
#   ('least', 'JJS'),
#   ('take', 'VB'),
#   ('joker', 'NN'),
#   ('differ', 'NN'),
#   ('ledger', 'NN'),
#   ('id', 'NNS'),
#   ('say', 'VBP'),
#   ('equal', 'JJ'),
#   ('good', 'JJ'),
#   ('main', 'JJ'),
#   ('differ', 'NN'),
#   ('might', 'MD'),
#   ('ledger', 'VB'),
#   ('joker', 'NN'),
#   ('ration', 'NN'),
#   ('act', 'NN'),
#   ('insan', 'JJ'),
#   ('phoenix', 'JJ'),
#   ('insan', 'JJ'),
#   ('rootdespit', 'NN'),
#   ('movi', 'NN'),
#   ('superhero', 'NN'),
#   ('villain', 'NN'),
#   ('joker', 'NN'),
#   ('much', 'JJ'),
#   ('superior', 'JJ'),
#   ('movi', 'NN'),
#   ('genr', 'NN'),
#   ('id', 'NN'),
#   ('exclud', 'NN'),
#   ('dark', 'NN'),
#   ('knight', 'VBD'),
#   ('trilog', 'NN'),
#   ('joker', 'NN'),
#   ('easili', 'RB'),
#   ('good', 'JJ'),
#   ('nolan', 'NN'),
#   ('movi', 'VBP'),
#   ('least', 'JJS'),
#   ('close', 'JJ'),
#   ('smallscal', 'JJ'),
#   ('film', 'NN'),
#   ('distinct', 'JJ'),
#   ('style', 'NN'),
#   ('cinematographi', 'NN'),
#   ('appreci', 'NN'),
#   ('set', 'VBN'),
#   ('cinephil', 'NN'),
#   ('refer', 'NN'),
#   ('howev', 'NN'),
#   ('feel', 'NN'),
#   ('forc', 'JJ'),
#   ('overli', 'NN'),
#   ('opress', 'NN'),
#   ('notabl', 'IN'),
#   ('similar', 'JJ'),
#   ('scorses', 'NNS'),
#   ('taxi', 'VBP'),
#   ('driver', 'RB'),
#   ('king', 'VBG'),
#   ('comedi', 'NN'),
#   ('also', 'RB'),
#   ('chaplin', 'VBZ'),
#   ('modern', 'JJ'),
#   ('time', 'NN'),
#   ('somewhat', 'WP'),
#   ('referencedi', 'VBZ'),
#   ('eager', 'JJ'),
#   ('see', 'NN'),
#   ('noncomed', 'JJ'),
#   ('effort', 'NN'),
#   ('todd', 'NN'),
#   ('phillip', 'NN'),
#   ('movi', 'NN'),
#   ('far', 'RB'),
#   ('probabl', 'JJ'),
#   ('best', 'JJS'),
#   ('worst', 'JJS'),
#   ('contest', 'NN'),
#   ('far', 'RB'),
#   ('dolor', 'JJ'),
#   ('gloria', 'NNS'),
#   ('upon', 'IN'),
#   ('time', 'NN'),
#   ('hollywood', 'NN'),
#   ('convinc', 'NN')],
#  [('sad', 'JJ'),
#   ('joaquin', 'NN'),
#   ('miss', 'NN'),
#   ('oscar', 'NN'),
#   ('gladiat', 'NN'),
#   ('compel', 'NN'),
#   ('villain', 'NN'),
#   ('quit', 'NN'),
#   ('confid', 'NN'),
#   ('win', 'VBP'),
#   ('joker', 'NN'),
#   ('damn', 'NN'),
#   ('movi', 'JJ'),
#   ('keep', 'VB'),
#   ('u', 'JJ'),
#   ('toe', 'NN'),
#   ('time', 'NN'),
#   ('unpredict', 'JJ'),
#   ('storylin', 'NN'),
#   ('realli', 'NN'),
#   ('deep', 'JJ'),
#   ('interest', 'NN'),
#   ('plot', 'NN'),
#   ('forget', 'VB'),
#   ('mention', 'NN'),
#   ('act', 'NN'),
#   ('damn', 'NN'),
#   ('niro', 'JJ'),
#   ('joaquin', 'NN'),
#   ('teach', 'NN'),
#   ('u', 'JJ'),
#   ('realli', 'NN'),
#   ('star', 'NN'),
#   ('act', 'NN'),
#   ('enjoy', 'VB'),
#   ('movi', 'JJ'),
#   ('get', 'VB'),
#   ('wine', 'JJ'),
#   ('hand', 'NN'),
#   ('close', 'RB'),
#   ('curtain', 'JJ'),
#   ('turn', 'NN'),
#   ('ur', 'JJ'),
#   ('cellphon', 'NN'),
#   ('put', 'VBD'),
#   ('disturb', 'RP'),
#   ('sign', 'NN'),
#   ('ur', 'JJ'),
#   ('door', 'NN'),
#   ('best', 'JJS'),
#   ('dark', 'NN'),
#   ('thriller', 'NN'),
#   ('suspens', 'VBZ'),
#   ('movi', 'JJ'),
#   ('get', 'NN'),
#   ('experi', 'NN')],
#  [],
#  [('movi', 'NN'),
#   ('caus', 'NN'),
#   ('audienc', 'NN'),
#   ('consid', 'NN'),
#   ('mani', 'NN'),
#   ('topic', 'NN'),
#   ('moral', 'JJ'),
#   ('particularli', 'NN'),
#   ('poor', 'JJ'),
#   ('choic', 'NN'),
#   ('made', 'VBD'),
#   ('joker', 'NN'),
#   ('joker', 'NN'),
#   ('relat', 'JJ'),
#   ('movi', 'NNS'),
#   ('antagonist', 'VBP'),
#   ('usual', 'JJ'),
#   ('think', 'VBP'),
#   ('give', 'JJ'),
#   ('realist', 'NN'),
#   ('view', 'NN'),
#   ('bad', 'JJ'),
#   ('peopl', 'NN'),
#   ('usual', 'JJ'),
#   ('bad', 'JJ'),
#   ('way', 'NN'),
#   ('societi', 'NN'),
#   ('often', 'RB'),
#   ('judg', 'JJ'),
#   ('import', 'NN'),
#   ('know', 'VBP'),
#   ('sympath', 'NN'),
#   ('joker', 'NN'),
#   ('toward', 'IN'),
#   ('begin', 'NN'),
#   ('movi', 'NNS'),
#   ('need', 'VBP'),
#   ('identifi', 'JJ'),
#   ('threat', 'NN'),
#   ('begin', 'NNS'),
#   ('make', 'VBP'),
#   ('certain', 'JJ'),
#   ('bad', 'JJ'),
#   ('choic', 'NN'),
#   ('movi', 'NN'),
#   ('suitabl', 'NN'),
#   ('adult', 'NN'),
#   ('will', 'MD'),
#   ('pick', 'VB'),
#   ('apart', 'RB'),
#   ('think', 'VBP'),
#   ('critic', 'JJ'),
#   ('isnt', 'NN'),
#   ('light', 'JJ'),
#   ('amus', 'NN'),
#   ('substanc', 'NNS'),
#   ('make', 'VBP'),
#   ('goodif', 'JJ'),
#   ('arent', 'NN'),
#   ('abl', 'NN'),
#   ('ponder', 'NN'),
#   ('underli', 'JJ'),
#   ('theme', 'NN'),
#   ('hand', 'NN'),
#   ('thought', 'VBD'),
#   ('isnt', 'RB'),
#   ('best', 'JJS'),
#   ('movi', 'NN')],
#  [('act', 'NN'),
#   ('cinematographi', 'NN'),
#   ('sound', 'JJ'),
#   ('design', 'NN'),
#   ('script', 'NN'),
#   ('phenomen', 'NNS'),
#   ('movi', 'VBP'),
#   ('triumph', 'JJ'),
#   ('joaquin', 'NN'),
#   ('pheonix', 'NN'),
#   ('deserv', 'NN'),
#   ('oscar', 'NN'),
#   ('win', 'VBP'),
#   ('tbh', 'NN')],
#  [('stop', 'VB'),
#   ('watch', 'NN'),
#   ('movi', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'JJ'),
#   ('award', 'NN'),
#   ('oscar', 'NN'),
#   ('tremend', 'NN'),
#   ('act', 'NN')],
#  [('quit', 'NN'),
#   ('reli', 'VBZ'),
#   ('critic', 'JJ'),
#   ('review', 'NN'),
#   ('year', 'NN'),
#   ('ago', 'RB'),
#   ('notic', 'JJ'),
#   ('movi', 'NNS'),
#   ('critic', 'JJ'),
#   ('rate', 'NN'),
#   ('low', 'JJ'),
#   ('viewer', 'NN'),
#   ('rate', 'NN'),
#   ('high', 'JJ'),
#   ('said', 'VBD'),
#   ('point', 'NN'),
#   ('critic', 'NN'),
#   ('movi', 'NN'),
#   ('oh', 'NN'),
#   ('wrong', 'JJ'),
#   ('went', 'VBD'),
#   ('saw', 'JJ'),
#   ('tonit', 'NN'),
#   ('mom', 'NN'),
#   ('went', 'VBD'),
#   ('skeptic', 'JJ'),
#   ('w', 'NN'),
#   ('low', 'JJ'),
#   ('expect', 'VBP'),
#   ('knew', 'VBN'),
#   ('expect', 'JJ'),
#   ('typic', 'NN'),
#   ('super', 'JJ'),
#   ('hero', 'NN'),
#   ('movi', 'NN'),
#   ('got', 'VBD'),
#   ('masterpiec', 'JJ'),
#   ('went', 'VBD'),
#   ('expect', 'JJ'),
#   ('sheer', 'NN'),
#   ('boredom', 'NN'),
#   ('instead', 'RB'),
#   ('edg', 'JJ'),
#   ('seat', 'NN'),
#   ('whole', 'JJ'),
#   ('time', 'NN'),
#   ('action', 'NN'),
#   ('edg', 'RB'),
#   ('seat', 'JJ'),
#   ('fear', 'NN'),
#   ('may', 'MD'),
#   ('say', 'VB'),
#   ('next', 'JJ'),
#   ('edg', 'JJ'),
#   ('seat', 'NN'),
#   ('see', 'VBP'),
#   ('charact', 'JJ'),
#   ('evolv', 'NNS'),
#   ('know', 'VBP'),
#   ('villain', 'VBP'),
#   ('batman', 'JJ'),
#   ('beyond', 'IN'),
#   ('geniu', 'JJ'),
#   ('joaquin', 'JJ'),
#   ('phoenix', 'NN'),
#   ('true', 'JJ'),
#   ('master', 'NN'),
#   ('perfect', 'JJ'),
#   ('art', 'NN'),
#   ('consum', 'NN'),
#   ('charact', 'NN'),
#   ('may', 'MD'),
#   ('place', 'VB'),
#   ('dont', 'NN'),
#   ('care', 'NN'),
#   ('movi', 'NNP'),
#   ('stori', 'NNP'),
#   ('act', 'NN'),
#   ('direct', 'JJ'),
#   ('effect', 'NN'),
#   ('everyon', 'NN'),
#   ('brought', 'VBD'),
#   ('game', 'NN'),
#   ('jp', 'NN'),
#   ('definit', 'NN'),
#   ('deserv', 'NN'),
#   ('nod', 'NN'),
#   ('win', 'VBP'),
#   ('role', 'NN'),
#   ('comparison', 'NN'),
#   ('jack', 'NN'),
#   ('nicholson', 'JJ'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('actor', 'NN'),
#   ('took', 'VBD'),
#   ('charact', 'NN'),
#   ('differ', 'NN'),
#   ('level', 'NN'),
#   ('differ', 'VBP'),
#   ('stori', 'JJ'),
#   ('point', 'NN'),
#   ('differ', 'NN'),
#   ('point', 'NN'),
#   ('time', 'NN'),
#   ('comparison', 'NN'),
#   ('would', 'MD'),
#   ('feasibl', 'VB'),
#   ('fair', 'JJ'),
#   ('actor', 'NN'),
#   ('embrac', 'NN'),
#   ('made', 'VBD'),
#   ('come', 'JJ'),
#   ('life', 'NN'),
#   ('geniu', 'NN'),
#   ('way', 'NN')],
#  [('need', 'NNS'),
#   ('say', 'VBP'),
#   ('everyth', 'JJ'),
#   ('movi', 'NN'),
#   ('master', 'NN'),
#   ('everi', 'NN'),
#   ('singl', 'JJ'),
#   ('way', 'NN'),
#   ('joker', 'NN'),
#   ('isnt', 'NN'),
#   ('awesom', 'IN'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('movi', 'NN'),
#   ('awesom', 'JJ'),
#   ('movi', 'JJ'),
#   ('period', 'NN'),
#   ('offer', 'NN'),
#   ('easi', 'VBZ'),
#   ('answer', 'JJR'),
#   ('unsettl', 'JJ'),
#   ('question', 'NN'),
#   ('rais', 'NN'),
#   ('cruel', 'NN'),
#   ('societi', 'NN'),
#   ('declin', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('fulli', 'JJ'),
#   ('commit', 'NN'),
#   ('perform', 'NN'),
#   ('todd', 'NN'),
#   ('phillip', 'NN'),
#   ('master', 'NN'),
#   ('albeit', 'IN'),
#   ('loo', 'JJ'),
#   ('reinvent', 'NN'),
#   ('dc', 'NN'),
#   ('sourc', 'NN'),
#   ('materi', 'NNS'),
#   ('make', 'VBP'),
#   ('joker', 'NN'),
#   ('film', 'NN'),
#   ('leav', 'VBP'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('fan', 'NN'),
#   ('nonfan', 'JJ'),
#   ('alik', 'NN'),
#   ('disturb', 'NN'),
#   ('move', 'NN'),
#   ('right', 'RB'),
#   ('way', 'NN')],
#  [('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('give', 'VBP'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('run', 'VB'),
#   ('money', 'NN'),
#   ('true', 'JJ'),
#   ('stori', 'NN'),
#   ('popcorn', 'JJ'),
#   ('fluff', 'NN'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('flick', 'NNS'),
#   ('take', 'VBP'),
#   ('kid', 'NNS'),
#   ('see', 'VBP'),
#   ('movi', 'JJ'),
#   ('shut', 'JJ'),
#   ('ballot', 'NN'),
#   ('oscar', 'NN'),
#   ('joaquin', 'NNS'),
#   ('take', 'VBP'),
#   ('one', 'CD'),
#   ('home', 'NN'),
#   ('hand', 'NN'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('origin', 'NN'),
#   ('stori', 'NN'),
#   ('ever', 'RB'),
#   ('put', 'VBD'),
#   ('downsid', 'JJ'),
#   ('movi', 'NN'),
#   ('stand', 'NN'),
#   ('alon', 'NN'),
#   ('film', 'NN'),
#   ('sequel', 'NN'),
#   ('tie', 'NN'),
#   ('dc', 'NN'),
#   ('univers', 'NNS'),
#   ('todd', 'VBP'),
#   ('philip', 'NNS'),
#   ('take', 'VB'),
#   ('joker', 'NN'),
#   ('one', 'CD'),
#   ('pure', 'NN'),
#   ('brillianc', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('joker', 'NN'),
#   ('deserv', 'NN'),
#   ('didnt', 'NN'),
#   ('steal', 'JJ'),
#   ('jack', 'NN'),
#   ('heath', 'NN'),
#   ('yet', 'RB'),
#   ('got', 'VBD'),
#   ('tast', 'NN')],
#  [('music', 'NN'),
#   ('intens', 'VBZ'),
#   ('realism', 'NN'),
#   ('perform', 'NN'),
#   ('stori', 'NN'),
#   ('perfect', 'JJ'),
#   ('combin', 'NN'),
#   ('everyth', 'NN'),
#   ('never', 'RB'),
#   ('felt', 'VBD'),
#   ('charact', 'NN'),
#   ('like', 'IN'),
#   ('joker', 'NN'),
#   ('could', 'MD'),
#   ('real', 'JJ'),
#   ('saw', 'VB'),
#   ('phoenix', 'NN'),
#   ('show', 'NN'),
#   ('u', 'JJ'),
#   ('joker', 'NN'),
#   ('societi', 'NN'),
#   ('show', 'NN'),
#   ('u', 'JJ'),
#   ('power', 'NN'),
#   ('obtain', 'VB'),
#   ('philip', 'JJ'),
#   ('hand', 'NN'),
#   ('perfect', 'JJ'),
#   ('choic', 'NN'),
#   ('music', 'NN'),
#   ('camera', 'NN'),
#   ('angl', 'NN'),
#   ('light', 'JJ'),
#   ('everi', 'NN'),
#   ('import', 'NN'),
#   ('factor', 'NN'),
#   ('overal', 'JJ'),
#   ('expect', 'VBP'),
#   ('stori', 'JJ'),
#   ('perfect', 'JJ'),
#   ('mani', 'NN'),
#   ('shock', 'NN'),
#   ('turn', 'VBP'),
#   ('happen', 'JJ'),
#   ('realli', 'NN'),
#   ('repres', 'NNS'),
#   ('today', 'NN'),
#   ('societi', 'VBP'),
#   ('first', 'JJ'),
#   ('screen', 'NN'),
#   ('would', 'MD'),
#   ('applaud', 'VB'),
#   ('min', 'NN')],
#  [('joaquin', 'NN'),
#   ('portray', 'NN'),
#   ('sociopath', 'NN'),
#   ('mental', 'JJ'),
#   ('unstabl', 'JJ'),
#   ('man', 'NN'),
#   ('transform', 'NN'),
#   ('icon', 'NN'),
#   ('joker', 'NN'),
#   ('non', 'NN'),
#   ('grippingli', 'NN'),
#   ('accur', 'VBP'),
#   ('realist', 'NN'),
#   ('touch', 'JJ'),
#   ('rendit', 'NN'),
#   ('dark', 'NN'),
#   ('disturb', 'NN'),
#   ('charact', 'NN'),
#   ('piec', 'NN'),
#   ('led', 'VBD'),
#   ('oscar', 'NN'),
#   ('worthi', 'NN'),
#   ('perform', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('realli', 'NN'),
#   ('feel', 'VB'),
#   ('bad', 'JJ'),
#   ('guy', 'NNS'),
#   ('make', 'VBP'),
#   ('heartbreak', 'JJ'),
#   ('inevit', 'NN'),
#   ('becom', 'NN'),
#   ('clown', 'VBN'),
#   ('princ', 'JJ'),
#   ('crime', 'NN'),
#   ('know', 'VBP'),
#   ('love', 'IN'),
#   ('although', 'IN'),
#   ('weve', 'NN'),
#   ('never', 'RB'),
#   ('seen', 'VBN'),
#   ('like', 'IN'),
#   ('see', 'NN'),
#   ('suffer', 'VBP'),
#   ('throughout', 'IN'),
#   ('movi', 'NN'),
#   ('point', 'NN'),
#   ('almost', 'RB'),
#   ('root', 'JJ'),
#   ('himk', 'NN'),
#   ('becom', 'NN'),
#   ('mass', 'NN'),
#   ('murder', 'NN'),
#   ('psyco', 'NN'),
#   ('clown', 'JJ'),
#   ('least', 'JJS'),
#   ('make', 'VBP'),
#   ('feel', 'VB'),
#   ('better', 'JJR'),
#   ('happen', 'VB'),
#   ('wish', 'NN'),
#   ('could', 'MD'),
#   ('avoid', 'VB'),
#   ('e', 'JJ'),
#   ('mess', 'NN'),
#   ('feel', 'VB'),
#   ('care', 'NN'),
#   ('time', 'NN'),
#   ('he', 'PRP'),
#   ('joker', 'VBZ'),
#   ('wish', 'JJ'),
#   ('couldv', 'NN'),
#   ('help', 'NN'),
#   ('there', 'RB'),
#   ('lot', 'VBZ'),
#   ('great', 'JJ'),
#   ('nod', 'JJ'),
#   ('greater', 'JJR'),
#   ('batman', 'NN'),
#   ('univers', 'NNS'),
#   ('yet', 'RB'),
#   ('movi', 'VBP'),
#   ('self', 'PRP'),
#   ('contain', 'VBP'),
#   ('charact', 'JJ'),
#   ('piec', 'JJ'),
#   ('mark', 'NN'),
#   ('great', 'JJ'),
#   ('movi', 'NN'),
#   ('act', 'NN'),
#   ('great', 'JJ'),
#   ('plot', 'NN'),
#   ('similar', 'JJ'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('brilliant', 'JJ'),
#   ('qualiti', 'NN'),
#   ('movi', 'NN'),
#   ('show', 'NN'),
#   ('dont', 'JJ'),
#   ('need', 'VBP'),
#   ('cgi', 'NNS'),
#   ('super', 'JJ'),
#   ('power', 'NN'),
#   ('great', 'JJ'),
#   ('villain', 'NN'),
#   ('superhero', 'NN'),
#   ('movi', 'NN'),
#   ('joke', 'NN'),
#   ('everyon', 'NN'),
#   ('get', 'VB'),
#   ('movi', 'JJ'),
#   ('rise', 'NN'),
#   ('joker', 'NN')],
#  [('perfect', 'JJ'),
#   ('portrait', 'NN'),
#   ('declin', 'NN'),
#   ('insan', 'JJ'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('portray', 'NN'),
#   ('flawlessli', 'NN'),
#   ('perform', 'NN'),
#   ('lifetim', 'NN'),
#   ('choreograph', 'NN'),
#   ('impecc', 'NN'),
#   ('todd', 'NN'),
#   ('phillip', 'NN'),
#   ('noth', 'DT'),
#   ('short', 'JJ'),
#   ('breathtak', 'NN'),
#   ('cinematographi', 'NN'),
#   ('backdrop', 'NN'),
#   ('ideolog', 'NN'),
#   ('origin', 'NN'),
#   ('film', 'NN'),
#   ('complex', 'JJ'),
#   ('charact', 'NN'),
#   ('compliment', 'NN'),
#   ('superb', 'NN'),
#   ('soundtrack', 'NN'),
#   ('act', 'NN'),
#   ('hauntingli', 'NN'),
#   ('beauti', 'NN'),
#   ('film', 'NN'),
#   ('defin', 'NN'),
#   ('edit', 'NN'),
#   ('bring', 'VBG'),
#   ('part', 'NN'),
#   ('plssssss', 'NN'),
#   ('want', 'VBP')],
#  [('phoenix', 'NN'),
#   ('convinc', 'NN'),
#   ('alway', 'NN'),
#   ('meant', 'JJ'),
#   ('joker', 'NN'),
#   ('movi', 'NN'),
#   ('went', 'VBD'),
#   ('beyond', 'IN'),
#   ('expect', 'JJ'),
#   ('mani', 'NN'),
#   ('emot', 'FW'),
#   ('went', 'VBD'),
#   ('coupl', 'JJ'),
#   ('hour', 'NN'),
#   ('think', 'VBP'),
#   ('rate', 'NN'),
#   ('r', 'NN'),
#   ('phoenix', 'NN'),
#   ('abl', 'NN'),
#   ('unlock', 'NN'),
#   ('joker', 'NN'),
#   ('full', 'JJ'),
#   ('psychot', 'NN'),
#   ('potenti', 'NN'),
#   ('charact', 'NN'),
#   ('meant', 'VBD'),
#   ('amaz', 'JJ'),
#   ('stori', 'NN'),
#   ('call', 'NN'),
#   ('mean', 'VBP'),
#   ('build', 'JJ'),
#   ('second', 'JJ'),
#   ('movi', 'NN'),
#   ('mayb', 'NN'),
#   ('one', 'CD'),
#   ('batman', 'NN'),
#   ('hope', 'VBP'),
#   ('high', 'JJ'),
#   ('point', 'NN'),
#   ('nevertheless', 'RB'),
#   ('brilliant', 'JJ'),
#   ('goddamn', 'NN'),
#   ('movi', 'NN'),
#   ('best', 'JJS'),
#   ('joker', 'NN'),
#   ('ever', 'RB'),
#   ('play', 'VBD'),
#   ('hand', 'NN')],
#  [('pool', 'NN'),
#   ('need', 'MD'),
#   ('money', 'NN'),
#   ('need', 'VB'),
#   ('digniti', 'JJ'),
#   ('respect', 'JJ'),
#   ('coz', 'NNS'),
#   ('take', 'VBP'),
#   ('human', 'JJ'),
#   ('dont', 'NN'),
#   ('money', 'NN'),
#   ('remind', 'NN'),
#   ('good', 'JJ'),
#   ('boy', 'NN'),
#   ('like', 'IN'),
#   ('politician', 'JJ'),
#   ('feel', 'NN'),
#   ('frustrat', 'NN'),
#   ('peopl', 'VBZ'),
#   ('lower', 'JJR'),
#   ('class', 'NN'),
#   ('accept', 'NN'),
#   ('fund', 'NN'),
#   ('champion', 'NN'),
#   ('movi', 'NN'),
#   ('joker', 'NN'),
#   ('life', 'NN'),
#   ('begin', 'VBP'),
#   ('get', 'VB')],
#  [('amaz', 'NN'),
#   ('stori', 'NN'),
#   ('brilliant', 'JJ'),
#   ('take', 'NN'),
#   ('magnific', 'NN'),
#   ('cinematographi', 'NN'),
#   ('someon', 'JJ'),
#   ('step', 'NN'),
#   ('safe', 'JJ'),
#   ('game', 'NN'),
#   ('play', 'NN'),
#   ('superhero', 'NN'),
#   ('movi', 'NN'),
#   ('joker', 'NN'),
#   ('movi', 'NN'),
#   ('also', 'RB'),
#   ('boy', 'VBZ'),
#   ('movi', 'JJ'),
#   ('gritti', 'NNS'),
#   ('real', 'JJ'),
#   ('insan', 'JJ'),
#   ('dark', 'NN'),
#   ('sometim', 'NN'),
#   ('quit', 'NN'),
#   ('disturb', 'NN'),
#   ('peopl', 'NN'),
#   ('dont', 'NN'),
#   ('want', 'VBP'),
#   ('accept', 'IN'),
#   ('what', 'WP'),
#   ('shown', 'VBN'),
#   ('movi', 'JJ'),
#   ('terribl', 'NN'),
#   ('realiti', 'NN'),
#   ('face', 'NN'),
#   ('everyday', 'JJ'),
#   ('refus', 'VBZ'),
#   ('proper', 'JJ'),
#   ('care', 'NN'),
#   ('normal', 'JJ'),
#   ('peopl', 'JJ'),
#   ('start', 'NN'),
#   ('compar', 'NN'),
#   ('movi', 'VBD'),
#   ('one', 'CD'),
#   ('greatest', 'JJS'),
#   ('like', 'IN'),
#   ('dark', 'NN'),
#   ('knight', 'NNP'),
#   ('act', 'NN'),
#   ('wise', 'NN'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('potray', 'NN'),
#   ('joker', 'NN'),
#   ('wouldnt', 'NNS'),
#   ('say', 'VBP'),
#   ('movi', 'RB'),
#   ('better', 'RB'),
#   ('otherwis', 'JJ'),
#   ('stand', 'VBP'),
#   ('tall', 'JJ'),
#   ('amongst', 'RB'),
#   ('greatest', 'JJS'),
#   ('like', 'IN'),
#   ('godfath', 'NN'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('citizen', 'VBP'),
#   ('kane', 'NN'),
#   ('dark', 'NN'),
#   ('knight', 'VBD'),
#   ('come', 'JJ'),
#   ('inevit', 'NN'),
#   ('comparison', 'NN'),
#   ('who', 'WP'),
#   ('better', 'RBR'),
#   ('joker', 'NN'),
#   ('heath', 'NN'),
#   ('joaquin', 'NN'),
#   ('answer', 'NN'),
#   ('phenomen', 'NNS'),
#   ('job', 'NN'),
#   ('joker', 'NN'),
#   ('charact', 'NN'),
#   ('fortun', 'JJ'),
#   ('play', 'NN'),
#   ('two', 'CD'),
#   ('greatest', 'JJS'),
#   ('actor', 'NN'),
#   ('definit', 'NN'),
#   ('top', 'JJ'),
#   ('contend', 'NN'),
#   ('oscar', 'NN'),
#   ('person', 'NN'),
#   ('think', 'VBP'),
#   ('would', 'MD'),
#   ('take', 'VB'),
#   ('away', 'RP'),
#   ('best', 'JJS'),
#   ('actor', 'NN'),
#   ('cinematographi', 'NN'),
#   ('origin', 'NN'),
#   ('score', 'NN'),
#   ('upon', 'IN'),
#   ('time', 'NN'),
#   ('hollywood', 'NN'),
#   ('lose', 'VB'),
#   ('makeup', 'NN'),
#   ('hairstyl', 'NN'),
#   ('categori', 'NN'),
#   ('would', 'MD'),
#   ('definit', 'VB'),
#   ('joker', 'NN')],
#  [('serious', 'JJ'),
#   ('unbeliev', 'JJ'),
#   ('dare', 'NN'),
#   ('say', 'VBP'),
#   ('better', 'JJR'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('doesnt', 'NN'),
#   ('win', 'VBP'),
#   ('oscar', 'NN'),
#   ('best', 'JJS'),
#   ('actor', 'NN'),
#   ('joker', 'NN'),
#   ('doesnt', 'NN'),
#   ('win', 'VB'),
#   ('least', 'JJS'),
#   ('best', 'JJS'),
#   ('screenplay', 'NN'),
#   ('one', 'CD'),
#   ('biggest', 'JJS'),
#   ('oscar', 'NN'),
#   ('snub', 'NN'),
#   ('time', 'NN')],
#  [('trailer', 'NN'),
#   ('movi', 'NN'),
#   ('may', 'MD'),
#   ('seem', 'VB'),
#   ('like', 'IN'),
#   ('potenti', 'JJ'),
#   ('action', 'NN'),
#   ('pack', 'NN'),
#   ('movi', 'NN'),
#   ('movi', 'NN'),
#   ('clearli', 'NN'),
#   ('came', 'VBD'),
#   ('theater', 'RB'),
#   ('intend', 'JJ'),
#   ('progress', 'NN'),
#   ('charact', 'NN'),
#   ('studi', 'NN'),
#   ('shouldnt', 'NN'),
#   ('go', 'VBP'),
#   ('movi', 'JJ'),
#   ('expect', 'VBP'),
#   ('intens', 'JJ'),
#   ('action', 'NN'),
#   ('joker', 'NN'),
#   ('know', 'VBD'),
#   ('past', 'JJ'),
#   ('movi', 'NN'),
#   ('arthur', 'NN'),
#   ('fleck', 'NN'),
#   ('becom', 'NN'),
#   ('jokeri', 'NN'),
#   ('seen', 'VBN'),
#   ('mani', 'JJ'),
#   ('bad', 'JJ'),
#   ('review', 'NN'),
#   ('bore', 'IN'),
#   ('slow', 'JJ'),
#   ('movi', 'NN'),
#   ('believ', 'NN'),
#   ('utter', 'NN'),
#   ('perfect', 'VBP'),
#   ('first', 'JJ'),
#   ('part', 'NN'),
#   ('movi', 'NN'),
#   ('begin', 'NN'),
#   ('understand', 'VBP'),
#   ('arthur', 'IN'),
#   ('person', 'NN'),
#   ('interact', 'JJ'),
#   ('everyon', 'JJ'),
#   ('life', 'NN'),
#   ('good', 'JJ'),
#   ('bad', 'JJ'),
#   ('whole', 'JJ'),
#   ('point', 'NN'),
#   ('charact', 'NN'),
#   ('studi', 'NN'),
#   ('evolut', 'VBP'),
#   ('far', 'RB'),
#   ('away', 'RB'),
#   ('one', 'CD'),
#   ('greatest', 'JJS'),
#   ('evolut', 'NN'),
#   ('charact', 'NN'),
#   ('ever', 'RB'),
#   ('seen', 'VBN'),
#   ('moviejoaquin', 'JJ'),
#   ('phoenix', 'NN'),
#   ('perform', 'NN'),
#   ('far', 'RB'),
#   ('best', 'JJS'),
#   ('act', 'NN'),
#   ('seen', 'VBN'),
#   ('movi', 'NN'),
#   ('possibl', 'NN'),
#   ('last', 'JJ'),
#   ('decad', 'NN'),
#   ('see', 'VBP'),
#   ('challeng', 'JJ'),
#   ('person', 'NN'),
#   ('challeng', 'NN'),
#   ('societi', 'JJ'),
#   ('complet', 'NN'),
#   ('break', 'NN'),
#   ('time', 'NN'),
#   ('joaquin', 'JJ'),
#   ('isnt', 'NN'),
#   ('act', 'NN'),
#   ('evolv', 'NN'),
#   ('throughout', 'IN'),
#   ('movi', 'JJ'),
#   ('anyon', 'NN'),
#   ('think', 'VBP'),
#   ('doesnt', 'NN'),
#   ('put', 'VBD'),
#   ('oscar', 'RP'),
#   ('win', 'JJ'),
#   ('perform', 'NN'),
#   ('theyr', 'NN'),
#   ('ef', 'NN'),
#   ('mind', 'NN'),
#   ('ye', 'JJ'),
#   ('movi', 'NN'),
#   ('slow', 'JJ'),
#   ('start', 'NN'),
#   ('couldnt', 'NN'),
#   ('jump', 'NN'),
#   ('joker', 'NN'),
#   ('chao', 'VBD'),
#   ('need', 'NN'),
#   ('know', 'NNS'),
#   ('came', 'VBD'),
#   ('begin', 'JJ'),
#   ('withth', 'JJ'),
#   ('whole', 'JJ'),
#   ('compil', 'NN'),
#   ('movi', 'NN'),
#   ('amaz', 'JJ'),
#   ('complet', 'NN'),
#   ('oscar', 'NN'),
#   ('deserv', 'NN'),
#   ('perform', 'NN'),
#   ('joaquin', 'NN'),
#   ('choreographi', 'NN'),
#   ('cinematographi', 'NN'),
#   ('score', 'NN'),
#   ('everyth', 'NN'),
#   ('perfect', 'JJ'),
#   ('harmoni', 'NN'),
#   ('may', 'MD'),
#   ('lot', 'VB'),
#   ('controversi', 'JJR'),
#   ('surround', 'NN'),
#   ('movi', 'NN'),
#   ('team', 'NN'),
#   ('put', 'VBD'),
#   ('togeth', 'RP'),
#   ('perfect', 'JJ'),
#   ('movi', 'NN'),
#   ('piti', 'NN'),
#   ('cant', 'NN'),
#   ('appreci', 'NN'),
#   ('tear', 'JJ'),
#   ('sweat', 'NN'),
#   ('emot', 'JJ'),
#   ('went', 'VBD'),
#   ('make', 'VB'),
#   ('moviei', 'NN'),
#   ('alway', 'RB'),
#   ('one', 'CD'),
#   ('side', 'NN'),
#   ('movi', 'NN'),
#   ('prefer', 'VBP'),
#   ('marvel', 'NN'),
#   ('dc', 'NN'),
#   ('feel', 'VBP'),
#   ('like', 'IN'),
#   ('marvel', 'NN'),
#   ('sooo', 'RB'),
#   ('much', 'RB'),
#   ('better', 'RBR'),
#   ('overal', 'JJ'),
#   ('movi', 'NN'),
#   ('dc', 'NN'),
#   ('put', 'VBD'),
#   ('trash', 'JJ'),
#   ('joker', 'NN'),
#   ('far', 'RB'),
#   ('away', 'RB'),
#   ('favorit', 'JJ'),
#   ('comic', 'JJ'),
#   ('movi', 'NN'),
#   ('even', 'RB'),
#   ('though', 'IN'),
#   ('take', 'VB'),
#   ('complet', 'NN'),
#   ('differ', 'NN'),
#   ('spin', 'NN'),
#   ('comic', 'JJ'),
#   ('movi', 'NN'),
#   ('appreci', 'NN'),
#   ('evolut', 'NN'),
#   ('appreci', 'NN'),
#   ('movi', 'JJ'),
#   ('action', 'NN'),
#   ('movi', 'NN'),
#   ('realli', 'NN'),
#   ('rip', 'NN'),
#   ('tear', 'IN'),
#   ('emot', 'JJ'),
#   ('one', 'CD'),
#   ('movi', 'NN'),
#   ('ad', 'NN'),
#   ('wild', 'JJ'),
#   ('suspens', 'NNS'),
#   ('kick', 'VBP'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('movi', 'NN'),
#   ('done', 'VBN')],
#  [('one', 'CD'),
#   ('best', 'JJS'),
#   ('movi', 'NN'),
#   ('year', 'NN'),
#   ('oscar', 'NN'),
#   ('worthyjoaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('deliv', 'VBZ'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('perform', 'NN'),
#   ('ive', 'JJ'),
#   ('ever', 'RB'),
#   ('scene', 'NN')],
#  [('incred', 'VBN'),
#   ('ride', 'NN'),
#   ('almost', 'RB'),
#   ('motionless', 'JJ'),
#   ('throughout', 'IN'),
#   ('watch', 'NN'),
#   ('awe', 'NN'),
#   ('perform', 'NN'),
#   ('lifetim', 'NN'),
#   ('transit', 'NN'),
#   ('troubl', 'NN'),
#   ('man', 'NN'),
#   ('monster', 'NN'),
#   ('hound', 'VBD'),
#   ('score', 'RB'),
#   ('directli', 'JJ'),
#   ('drove', 'VB'),
#   ('goosebump', 'NN'),
#   ('cinematographi', 'NN'),
#   ('made', 'VBD'),
#   ('feel', 'NN'),
#   ('like', 'IN'),
#   ('fli', 'NN'),
#   ('gotham', 'NN'),
#   ('look', 'NN'),
#   ('arthur', 'JJ'),
#   ('master', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('gave', 'VBD'),
#   ('nod', 'CC'),
#   ('jerri', 'JJ'),
#   ('lewi', 'NN'),
#   ('ignor', 'NN'),
#   ('dc', 'NN'),
#   ('ignor', 'JJ'),
#   ('batman', 'NN'),
#   ('work', 'NN'),
#   ('art', 'RB'),
#   ('right', 'JJ')],
#  [('movi', 'NN'),
#   ('masterpiec', 'NN'),
#   ('absolut', 'NN'),
#   ('epitom', 'NN'),
#   ('dc', 'NN'),
#   ('movi', 'NN'),
#   ('dark', 'NN'),
#   ('emot', 'NN'),
#   ('thought', 'VBD'),
#   ('provok', 'JJ'),
#   ('action', 'NN'),
#   ('action', 'NN'),
#   ('action', 'NN'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('movi', 'NN'),
#   ('ive', 'JJ'),
#   ('seen', 'VBN'),
#   ('long', 'RB'),
#   ('timecrit', 'JJ'),
#   ('definit', 'NN'),
#   ('lost', 'VBD'),
#   ('touch', 'JJ'),
#   ('public', 'JJ'),
#   ('ignor', 'NN'),
#   ('one', 'CD'),
#   ('favor', 'NN'),
#   ('watch', 'NN'),
#   ('itand', 'NN'),
#   ('rememb', 'VBD'),
#   ('good', 'JJ'),
#   ('one', 'CD'),
#   ('anoth', 'DT'),
#   ('dont', 'NN'),
#   ('know', 'VBP'),
#   ('someon', 'NN'),
#   ('el', 'NN'),
#   ('go', 'VBP')],
#  [('dc', 'NN'),
#   ('still', 'RB'),
#   ('give', 'VB'),
#   ('u', 'JJ'),
#   ('compel', 'NN'),
#   ('movi', 'NN'),
#   ('wasnt', 'NN'),
#   ('quit', 'NN'),
#   ('hype', 'NN'),
#   ('mean', 'NN'),
#   ('origin', 'NN'),
#   ('stori', 'NN'),
#   ('villain', 'NN'),
#   ('made', 'VBD'),
#   ('director', 'NN'),
#   ('hangov', 'NN'),
#   ('movi', 'NN'),
#   ('could', 'MD'),
#   ('even', 'RB'),
#   ('expect', 'VB'),
#   ('review', 'JJ'),
#   ('start', 'NN'),
#   ('drop', 'NN'),
#   ('still', 'RB'),
#   ('wasnt', 'JJ'),
#   ('sure', 'RB'),
#   ('would', 'MD'),
#   ('like', 'VB'),
#   ('saw', 'JJ'),
#   ('way', 'NN'),
#   ('better', 'RBR'),
#   ('thought', 'NN'),
#   ('would', 'MD'),
#   ('wont', 'VB'),
#   ('call', 'VB'),
#   ('masterpiec', 'JJ'),
#   ('definit', 'NN'),
#   ('top', 'JJ'),
#   ('dc', 'NN'),
#   ('film', 'NN'),
#   ('timesgood', 'NN'),
#   ('there', 'RB'),
#   ('hardli', 'VBZ'),
#   ('anyth', 'JJ'),
#   ('bad', 'JJ'),
#   ('joker', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('great', 'JJ'),
#   ('job', 'NN'),
#   ('bring', 'NN'),
#   ('charact', 'JJ'),
#   ('life', 'NN'),
#   ('rather', 'RB'),
#   ('typic', 'JJ'),
#   ('superherosupervillain', 'VB'),
#   ('origin', 'JJ'),
#   ('stori', 'NNS'),
#   ('get', 'VBP'),
#   ('see', 'VB'),
#   ('psycholog', 'JJ'),
#   ('drama', 'NN'),
#   ('horror', 'NN'),
#   ('thank', 'JJ'),
#   ('god', 'NN'),
#   ('got', 'VBD'),
#   ('love', 'JJ'),
#   ('genr', 'NN'),
#   ('love', 'NN'),
#   ('film', 'NN'),
#   ('like', 'IN'),
#   ('infin', 'JJ'),
#   ('war', 'NN'),
#   ('day', 'NN'),
#   ('futur', 'VBD'),
#   ('past', 'JJ'),
#   ('endgam', 'NN'),
#   ('raimi', 'NN'),
#   ('spiderman', 'JJ'),
#   ('occasion', 'NN'),
#   ('realli', 'NN'),
#   ('good', 'JJ'),
#   ('take', 'VB'),
#   ('break', 'NN'),
#   ('film', 'NN'),
#   ('kind', 'NN'),
#   ('categori', 'NN'),
#   ('film', 'NN'),
#   ('like', 'IN'),
#   ('unbreak', 'JJ'),
#   ('basic', 'JJ'),
#   ('movi', 'NN'),
#   ('spoiler', 'NN'),
#   ('ahead', 'RB'),
#   ('arthur', 'JJ'),
#   ('torment', 'NN'),
#   ('societi', 'NN'),
#   ('mental', 'JJ'),
#   ('unstabl', 'JJ'),
#   ('loner', 'NN'),
#   ('lose', 'JJ'),
#   ('mind', 'NN'),
#   ('constant', 'JJ'),
#   ('torment', 'NN'),
#   ('hell', 'NN'),
#   ('break', 'VB'),
#   ('loo', 'NN'),
#   ('that', 'IN'),
#   ('movi', 'NN'),
#   ('show', 'NN'),
#   ('would', 'MD'),
#   ('quit', 'VB'),
#   ('difficult', 'JJ'),
#   ('give', 'JJ'),
#   ('realli', 'NN'),
#   ('good', 'JJ'),
#   ('stori', 'NN'),
#   ('plot', 'NN'),
#   ('like', 'IN'),
#   ('sinc', 'NN'),
#   ('mani', 'NN'),
#   ('movi', 'NN'),
#   ('kind', 'NN'),
#   ('plot', 'NN'),
#   ('aw', 'NN'),
#   ('crappi', 'VBP'),
#   ('one', 'CD'),
#   ('includ', 'JJ'),
#   ('complet', 'NN'),
#   ('like', 'IN'),
#   ('movi', 'JJ'),
#   ('mean', 'JJ'),
#   ('screenplay', 'NN'),
#   ('direct', 'JJ'),
#   ('work', 'NN'),
#   ('feel', 'NN'),
#   ('arthur', 'IN'),
#   ('whenev', 'JJ'),
#   ('movi', 'NNS'),
#   ('ask', 'VBP'),
#   ('want', 'VBP'),
#   ('root', 'NN'),
#   ('arthur', 'NN'),
#   ('know', 'VBP'),
#   ('mean', 'NN'),
#   ('incred', 'JJ'),
#   ('terribl', 'JJ'),
#   ('thing', 'NN'),
#   ('happen', 'VB'),
#   ('see', 'NN'),
#   ('slowli', 'JJ'),
#   ('transit', 'NN'),
#   ('joker', 'NN'),
#   ('complet', 'NN'),
#   ('turn', 'NN'),
#   ('joker', 'NN'),
#   ('worth', 'NN'),
#   ('round', 'NN'),
#   ('applaus', 'IN'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('well', 'RB'),
#   ('terrifi', 'JJ'),
#   ('action', 'NN'),
#   ('joker', 'NN'),
#   ('whenev', 'NN'),
#   ('snap', 'JJ'),
#   ('crazi', 'NN'),
#   ('stuff', 'NN'),
#   ('happen', 'VB'),
#   ('without', 'IN'),
#   ('get', 'NN'),
#   ('spoiler', 'NN'),
#   ('would', 'MD'),
#   ('say', 'VB'),
#   ('short', 'JJ'),
#   ('mani', 'NN'),
#   ('quotabl', 'JJ'),
#   ('line', 'NN'),
#   ('make', 'VBP'),
#   ('sen', 'NN'),
#   ('whatev', 'NN'),
#   ('joker', 'NN'),
#   ('psychopath', 'NN'),
#   ('say', 'VBP'),
#   ('realist', 'NN'),
#   ('sane', 'NN'),
#   ('person', 'NN'),
#   ('say', 'VBP'),
#   ('obvious', 'JJ'),
#   ('sick', 'JJ'),
#   ('terrifi', 'NN'),
#   ('gruesom', 'NN'),
#   ('joker', 'NN'),
#   ('moment', 'NN'),
#   ('proper', 'JJ'),
#   ('joker', 'NN'),
#   ('movi', 'NN'),
#   ('clear', 'JJ'),
#   ('trailer', 'NN'),
#   ('there', 'EX'),
#   ('batman', 'JJ'),
#   ('spoiler', 'NN'),
#   ('batman', 'NN'),
#   ('refer', 'VBP'),
#   ('support', 'NN'),
#   ('movi', 'NN'),
#   ('couldv', 'NN'),
#   ('creat', 'NN'),
#   ('mess', 'NN'),
#   ('might', 'MD'),
#   ('felt', 'VB'),
#   ('like', 'IN'),
#   ('shoehorn', 'JJ'),
#   ('plotlin', 'NN'),
#   ('play', 'NN'),
#   ('proper', 'JJ'),
#   ('support', 'NN'),
#   ('main', 'JJ'),
#   ('stori', 'JJ'),
#   ('transit', 'NN'),
#   ('arthur', 'IN'),
#   ('jokermix', 'NN'),
#   ('good', 'JJ'),
#   ('thing', 'NN'),
#   ('movi', 'NN'),
#   ('psycho', 'JJ'),
#   ('horror', 'NN'),
#   ('vibe', 'NN'),
#   ('couldv', 'NN'),
#   ('origin', 'VBP'),
#   ('like', 'IN'),
#   ('mani', 'FW'),
#   ('other', 'JJ'),
#   ('point', 'NN'),
#   ('similar', 'JJ'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('scorses', 'VBZ'),
#   ('wasnt', 'JJ'),
#   ('copi', 'NN'),
#   ('past', 'IN'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('part', 'NN'),
#   ('make', 'VBP'),
#   ('obviou', 'NN'),
#   ('movi', 'NN'),
#   ('inspir', 'NN'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('necessarili', 'RB'),
#   ('bad', 'JJ'),
#   ('thing', 'NN'),
#   ('movi', 'NN'),
#   ('element', 'JJ'),
#   ('homageish', 'JJ'),
#   ('way', 'NN'),
#   ('look', 'NN'),
#   ('well', 'RB'),
#   ('made', 'VBD'),
#   ('couldv', 'NNS'),
#   ('slightli', 'JJ'),
#   ('origin', 'NN'),
#   ('may', 'MD'),
#   ('feel', 'VB'),
#   ('bit', 'RB'),
#   ('slow', 'JJ'),
#   ('peopl', 'NN'),
#   ('though', 'IN'),
#   ('worth', 'JJ'),
#   ('timemi', 'NNS'),
#   ('take', 'VBP'),
#   ('controversi', 'NN'),
#   ('happen', 'VB'),
#   ('moron', 'NN'),
#   ('might', 'MD'),
#   ('watch', 'VB'),
#   ('film', 'NN'),
#   ('caus', 'NN'),
#   ('violenc', 'NN'),
#   ('happen', 'VB'),
#   ('violent', 'NN'),
#   ('movi', 'NN'),
#   ('even', 'RB'),
#   ('though', 'IN'),
#   ('justifi', 'NN'),
#   ('joker', 'NN'),
#   ('action', 'NN'),
#   ('doesnt', 'NN'),
#   ('show', 'NN'),
#   ('right', 'JJ'),
#   ('speak', 'NN'),
#   ('violenc', 'NN'),
#   ('psycholog', 'NN'),
#   ('compel', 'VBP'),
#   ('horror', 'NN'),
#   ('le', 'NN'),
#   ('violent', 'JJ'),
#   ('deadpool', 'NN'),
#   ('feel', 'VB'),
#   ('violent', 'JJ'),
#   ('seriou', 'NN'),
#   ('movi', 'NN'),
#   ('glorif', 'JJ'),
#   ('side', 'NN'),
#   ('psychopath', 'NN'),
#   ('complet', 'NN'),
#   ('total', 'JJ'),
#   ('nonsenseconclus', 'JJ'),
#   ('must', 'MD'),
#   ('watch', 'VB'),
#   ('dont', 'NN'),
#   ('need', 'NN'),
#   ('follow', 'VBP'),
#   ('dc', 'VB'),
#   ('movi', 'NN'),
#   ('understand', 'NN'),
#   ('expect', 'VBP'),
#   ('typic', 'NN'),
#   ('superhero', 'JJ'),
#   ('action', 'NN'),
#   ('film', 'NN'),
#   ('cgi', 'NN'),
#   ('battl', 'NN'),
#   ('spectacl', 'NN'),
#   ('wrong', 'JJ'),
#   ('expect', 'NN'),
#   ('might', 'MD'),
#   ('ruin', 'VB'),
#   ('experi', 'JJ'),
#   ('el', 'NN'),
#   ('found', 'VBD'),
#   ('better', 'JJR'),
#   ('dark', 'NN'),
#   ('knight', 'VBD'),
#   ('rise', 'NN'),
#   ('tdkr', 'NN'),
#   ('one', 'CD'),
#   ('favorit', 'NN'),
#   ('genr', 'NN'),
#   ('nolan', 'NN'),
#   ('movi', 'VBP'),
#   ('replac', 'NN'),
#   ('anoth', 'DT'),
#   ('movi', 'JJ'),
#   ('list', 'NN'),
#   ('may', 'MD'),
#   ('consid', 'VB'),
#   ('great', 'JJ'),
#   ('one', 'CD'),
#   ('last', 'JJ'),
#   ('thing', 'NN'),
#   ('peopl', 'NN'),
#   ('caus', 'NN'),
#   ('violenc', 'NN'),
#   ('joker', 'NN'),
#   ('would', 'MD'),
#   ('equival', 'VB'),
#   ('good', 'JJ'),
#   ('bad', 'JJ'),
#   ('ugli', 'NN'),
#   ('inspir', 'NN'),
#   ('three', 'CD'),
#   ('peopl', 'NN'),
#   ('gun', 'NN'),
#   ('duel', 'NN'),
#   ('goldratingscor', 'NN'),
#   ('grade', 'NN')],
#  [('joker', 'NN'),
#   ('liter', 'NN'),
#   ('achiev', 'NN'),
#   ('cinemat', 'NN'),
#   ('histori', 'NN'),
#   ('there', 'RB'),
#   ('doubt', 'VBZ'),
#   ('peopl', 'NN'),
#   ('compar', 'NN'),
#   ('endgam', 'NN'),
#   ('movi', 'JJ'),
#   ('way', 'NN'),
#   ('complet', 'NN'),
#   ('differ', 'VB'),
#   ('endgam', 'JJ'),
#   ('best', 'JJS'),
#   ('genr', 'NN'),
#   ('talk', 'NN'),
#   ('joker', 'NN'),
#   ('say', 'VBP'),
#   ('beauti', 'JJ'),
#   ('present', 'JJ'),
#   ('storylin', 'NN'),
#   ('direct', 'JJ'),
#   ('screenplay', 'NN'),
#   ('peak', 'NN'),
#   ('great', 'JJ'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('smile', 'JJ'),
#   ('earth', 'NN')],
#  [('movi', 'NN'),
#   ('excel', 'NN'),
#   ('amaz', 'NN'),
#   ('begin', 'VBP'),
#   ('joaquin', 'CD'),
#   ('person', 'NN'),
#   ('seen', 'VBN'),
#   ('evolv', 'NN'),
#   ('joker', 'NN'),
#   ('end', 'NN'),
#   ('joker', 'NN'),
#   ('difficult', 'JJ'),
#   ('charact', 'JJ'),
#   ('think', 'VB'),
#   ('joaquin', 'NN')],
#  [('wow', 'NNS'),
#   ('say', 'VBP'),
#   ('brilliant', 'JJ'),
#   ('phoenix', 'NN'),
#   ('act', 'NN'),
#   ('perform', 'NN'),
#   ('shortcutmovi', 'JJ'),
#   ('year', 'NN')],
#  [('plea', 'NN'),
#   ('go', 'VBP'),
#   ('watch', 'NN'),
#   ('movi', 'NN'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('ive', 'JJ'),
#   ('ever', 'RB'),
#   ('wrote', 'VBD'),
#   ('review', 'NN'),
#   ('app', 'RB'),
#   ('ive', 'JJ'),
#   ('use', 'NN'),
#   ('read', 'NN'),
#   ('review', 'NN'),
#   ('year', 'NN'),
#   ('that', 'WDT'),
#   ('good', 'JJ'),
#   ('film', 'NN'),
#   ('dark', 'NN'),
#   ('grimi', 'NN'),
#   ('disturb', 'NN'),
#   ('exactli', 'NN'),
#   ('origin', 'NN'),
#   ('film', 'NN'),
#   ('joker', 'NN'),
#   ('doubt', 'NN'),
#   ('win', 'VB'),
#   ('multipl', 'NN'),
#   ('oscar', 'NN'),
#   ('favor', 'NN'),
#   ('go', 'VBP'),
#   ('see', 'VB')],
#  [('creativ', 'NN'),
#   ('actor', 'NN'),
#   ('joaquin', 'NN'),
#   ('creativ', 'NN'),
#   ('embodi', 'JJ'),
#   ('role', 'NN'),
#   ('joker', 'NN'),
#   ('film', 'NN'),
#   ('deserv', 'NN')],
#  [('end', 'NN'),
#   ('matter', 'NN'),
#   ('movi', 'NN'),
#   ('movi', 'NN'),
#   ('kind', 'NN'),
#   ('end', 'NN'),
#   ('would', 'MD'),
#   ('leav', 'VB'),
#   ('mani', 'JJ'),
#   ('speechless', 'NN'),
#   ('inde', 'NN'),
#   ('masterpiec', 'NN')],
#  [('yesterday', 'NN'),
#   ('day', 'NN'),
#   ('understand', 'VB'),
#   ('touch', 'JJ'),
#   ('histori', 'NN'),
#   ('movi', 'NNS'),
#   ('drag', 'VBP'),
#   ('deepest', 'JJS'),
#   ('thought', 'NN'),
#   ('darkest', 'NN'),
#   ('secret', 'JJ'),
#   ('suffer', 'NN'),
#   ('masterpiec', 'NN'),
#   ('grind', 'NN'),
#   ('like', 'IN'),
#   ('meat', 'NN'),
#   ('grinder', 'NN'),
#   ('watch', 'NN'),
#   ('silenc', 'NN'),
#   ('open', 'JJ'),
#   ('mouth', 'NN'),
#   ('like', 'IN'),
#   ('whole', 'JJ'),
#   ('cinema', 'NN'),
#   ('dont', 'NN'),
#   ('like', 'IN'),
#   ('comic', 'JJ'),
#   ('movi', 'NN'),
#   ('marvel', 'NN'),
#   ('pompou', 'NN'),
#   ('absurd', 'JJ'),
#   ('insipid', 'JJ'),
#   ('opinion', 'NN'),
#   ('art', 'NN'),
#   ('attract', 'VB'),
#   ('dc', 'JJ'),
#   ('movi', 'NN'),
#   ('dc', 'NN'),
#   ('made', 'VBD'),
#   ('histori', 'NNS'),
#   ('made', 'VBN'),
#   ('art', 'RB'),
#   ('made', 'VBN'),
#   ('drama', 'NN'),
#   ('understand', 'JJ'),
#   ('watch', 'NN'),
#   ('exampl', 'NN'),
#   ('aveng', 'NN'),
#   ('leagu', 'RBR'),
#   ('justic', 'JJ'),
#   ('eat', 'NN'),
#   ('mcdonald', 'NNS'),
#   ('hamburg', 'VBP'),
#   ('watch', 'NN'),
#   ('joker', 'NN'),
#   ('eat', 'VBD'),
#   ('stake', 'NN'),
#   ('luxuri', 'NN'),
#   ('restaur', 'NN'),
#   ('world', 'NN')],
#  [('joker', 'NN'),
#   ('without', 'IN'),
#   ('doubt', 'NN'),
#   ('new', 'JJ'),
#   ('favorit', 'NN'),
#   ('dc', 'NN'),
#   ('film', 'NN'),
#   ('dark', 'JJ'),
#   ('gritti', 'NNS'),
#   ('enough', 'RB'),
#   ('psycholog', 'VBP'),
#   ('twist', 'JJ'),
#   ('keep', 'NN'),
#   ('guess', 'NN'),
#   ('begin', 'JJ'),
#   ('end', 'NN'),
#   ('noth', 'DT'),
#   ('taken', 'VBN'),
#   ('face', 'NN'),
#   ('valu', 'NN'),
#   ('film', 'NN'),
#   ('forc', 'NN'),
#   ('think', 'VBP'),
#   ('begin', 'JJ'),
#   ('end', 'VBP'),
#   ('dont', 'NN'),
#   ('listen', 'JJ'),
#   ('critic', 'JJ'),
#   ('one', 'CD'),
#   ('worth', 'NN'),
#   ('watch', 'NN'),
#   ('multipl', 'NN'),
#   ('time', 'NN'),
#   ('theater', 'NN')],
#  [('batman', 'NN'),
#   ('fan', 'NN'),
#   ('particularli', 'JJ'),
#   ('fond', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('movi', 'NN'),
#   ('truli', 'NN'),
#   ('except', 'IN'),
#   ('start', 'NN'),
#   ('slow', 'VB'),
#   ('built', 'VBN'),
#   ('viscer', 'NN'),
#   ('satisfi', 'NN'),
#   ('crescendo', 'NN'),
#   ('never', 'RB'),
#   ('thought', 'VBN'),
#   ('would', 'MD'),
#   ('root', 'VB'),
#   ('joker', 'NN'),
#   ('found', 'VBN'),
#   ('throughout', 'IN'),
#   ('movi', 'NN'),
#   ('joker', 'NN'),
#   ('pain', 'NN'),
#   ('palpabl', 'NN'),
#   ('fill', 'NN'),
#   ('oscar', 'NN'),
#   ('pool', 'NN'),
#   ('card', 'NN'),
#   ('right', 'NN'),
#   ('nowp', 'NN'),
#   ('movi', 'NN'),
#   ('dark', 'JJ'),
#   ('violent', 'JJ'),
#   ('decidedli', 'NN'),
#   ('super', 'NN'),
#   ('hero', 'NN'),
#   ('movi', 'NN'),
#   ('leav', 'NN'),
#   ('kid', 'VBD'),
#   ('home', 'NN')],
#  [('best', 'JJS'),
#   ('act', 'NN'),
#   ('stori', 'NN'),
#   ('oscar', 'NN'),
#   ('win', 'VBP'),
#   ('movi', 'NN')],
#  [('realiti', 'NN'),
#   ('far', 'RB'),
#   ('fiction', 'NN'),
#   ('what', 'WP'),
#   ('made', 'VBD'),
#   ('movi', 'JJ'),
#   ('oscar', 'NN'),
#   ('winner', 'NN'),
#   ('actor', 'NN'),
#   ('made', 'VBD'),
#   ('new', 'JJ'),
#   ('joker', 'NN'),
#   ('rivalri', 'VBZ'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('joker', 'NN'),
#   ('better', 'RBR'),
#   ('joker', 'NN'),
#   ('peopl', 'JJ'),
#   ('opinion', 'NN'),
#   ('piec', 'NNS'),
#   ('art', 'VBP')],
#  [('wow', 'NN'),
#   ('honestli', 'NN'),
#   ('got', 'VBD'),
#   ('ta', 'RB'),
#   ('tell', 'VB'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('movi', 'NN'),
#   ('ive', 'NN'),
#   ('seen', 'VBN'),
#   ('year', 'NN'),
#   ('cinematographi', 'NN'),
#   ('thump', 'NN'),
#   ('sadden', 'JJ'),
#   ('soundtrack', 'NN'),
#   ('way', 'NN'),
#   ('omg', 'IN'),
#   ('perform', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('dark', 'NN'),
#   ('evolv', 'JJ'),
#   ('twist', 'NN'),
#   ('wow', 'NN'),
#   ('feel', 'VB'),
#   ('deep', 'JJ'),
#   ('bone', 'NN'),
#   ('emot', 'NN'),
#   ('portray', 'NN'),
#   ('jokerjust', 'NN'),
#   ('alon', 'NN'),
#   ('watch', 'NN'),
#   ('hear', 'NN'),
#   ('joker', 'NN'),
#   ('laugh', 'IN'),
#   ('twisti', 'NN'),
#   ('evil', 'NN'),
#   ('could', 'MD'),
#   ('hear', 'VB'),
#   ('sad', 'JJ'),
#   ('come', 'VBN'),
#   ('mouth', 'NN'),
#   ('could', 'MD'),
#   ('hear', 'VB'),
#   ('hour', 'NN'),
#   ('practic', 'JJ'),
#   ('laugh', 'NN'),
#   ('alon', 'NN'),
#   ('method', 'NN'),
#   ('act', 'NN'),
#   ('perfectli', 'JJ'),
#   ('point', 'NN'),
#   ('along', 'IN'),
#   ('subtl', 'JJ'),
#   ('gestur', 'NN'),
#   ('danc', 'NN'),
#   ('done', 'VBN'),
#   ('perfectli', 'NN'),
#   ('joker', 'NN'),
#   ('movi', 'NN'),
#   ('psycholog', 'NN'),
#   ('twist', 'NN'),
#   ('made', 'VBD'),
#   ('believ', 'JJ'),
#   ('immers', 'NNS'),
#   ('movi', 'VBP'),
#   ('total', 'JJ'),
#   ('shock', 'NN'),
#   ('overwhelm', 'NN'),
#   ('everyth', 'VBD'),
#   ('even', 'RB'),
#   ('left', 'JJ'),
#   ('cinema', 'NN'),
#   ('mindblownedwhen', 'NN'),
#   ('watch', 'NN'),
#   ('cinema', 'NN'),
#   ('half', 'NN'),
#   ('cinema', 'NN'),
#   ('cheer', 'NN'),
#   ('applaud', 'NN'),
#   ('certain', 'JJ'),
#   ('scene', 'NN'),
#   ('almost', 'RB'),
#   ('entir', 'JJ'),
#   ('patron', 'NN'),
#   ('stay', 'NN'),
#   ('last', 'JJ'),
#   ('credit', 'NN'),
#   ('u', 'JJ'),
#   ('look', 'VBP'),
#   ('close', 'JJ'),
#   ('even', 'RB'),
#   ('joker', 'NN'),
#   ('costum', 'NN'),
#   ('evolv', 'NN'),
#   ('chang', 'NN'),
#   ('time', 'NN'),
#   ('time', 'NN'),
#   ('base', 'NN'),
#   ('journey', 'NN'),
#   ('experienc', 'JJ'),
#   ('look', 'VBP'),
#   ('final', 'JJ'),
#   ('true', 'JJ'),
#   ('form', 'NN'),
#   ('look', 'NN'),
#   ('absolut', 'JJ'),
#   ('stun', 'NN'),
#   ('excit', 'NN'),
#   ('dialogu', 'NN'),
#   ('told', 'VBD'),
#   ('joker', 'NN'),
#   ('heartcrush', 'NN'),
#   ('made', 'VBD'),
#   ('felt', 'VBD'),
#   ('bad', 'JJ'),
#   ('joker', 'NN'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('side', 'NN'),
#   ('evil', 'JJ'),
#   ('charact', 'NN'),
#   ('mayb', 'NN'),
#   ('hero', 'NN'),
#   ('movi', 'NN'),
#   ('know', 'VBP'),
#   ('honestli', 'JJ'),
#   ('u', 'JJ'),
#   ('watch', 'NN'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('perform', 'NN'),
#   ('u', 'JJ'),
#   ('watch', 'NN'),
#   ('long', 'JJ'),
#   ('time', 'NN'),
#   ('movi', 'NNS'),
#   ('like', 'IN'),
#   ('deserv', 'NN'),
#   ('watch', 'NN'),
#   ('big', 'JJ'),
#   ('screen', 'NN'),
#   ('go', 'VBP'),
#   ('find', 'RB'),
#   ('best', 'RB'),
#   ('cinema', 'JJ'),
#   ('town', 'NN'),
#   ('enjoy', 'NN'),
#   ('wild', 'JJ'),
#   ('ride', 'NN'),
#   ('emot', 'VBD'),
#   ('fear', 'JJ'),
#   ('anger', 'NN'),
#   ('satisfi', 'NN')],
#  [('legendari', 'JJ'),
#   ('charact', 'NN'),
#   ('legendari', 'JJ'),
#   ('perform', 'NN'),
#   ('actor', 'NN'),
#   ('abl', 'JJ'),
#   ('move', 'NN'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('perform', 'VB'),
#   ('movi', 'JJ'),
#   ('total', 'JJ'),
#   ('worth', 'NN'),
#   ('movi', 'NN'),
#   ('deserv', 'NN'),
#   ('oscar', 'NN'),
#   ('showcas', 'NN'),
#   ('never', 'RB'),
#   ('seen', 'VBN'),
#   ('origin', 'NN'),
#   ('joker', 'NN'),
#   ('love', 'NN')],
#  [('notic', 'JJ'),
#   ('far', 'RB'),
#   ('left', 'JJ'),
#   ('journalist', 'JJ'),
#   ('new', 'JJ'),
#   ('york', 'NN'),
# ...
#   ('comicbook', 'NN'),
#   ('movi', 'NN'),
#   ('tell', 'NN'),
#   ('watch', 'NN')],
#  [('unsur', 'NN'),
#   ('would', 'MD'),
#   ('feel', 'VB'),
#   ('stand', 'VB'),
#   ('alon', 'NN'),
#   ('joker', 'NN'),
#   ('movi', 'NN'),
#   ('big', 'JJ'),
#   ('batman', 'NN'),
#   ('fan', 'NN'),
#   ('unsur', 'JJ'),
#   ('would', 'MD'),
#   ('like', 'VB'),
#   ('wrong', 'JJ'),
#   ('jaoquin', 'NNS'),
#   ('phoenix', 'VBP'),
#   ('perform', 'VB'),
#   ('disturb', 'NN'),
#   ('derrang', 'NN'),
#   ('arthur', 'NN'),
#   ('fleck', 'NN'),
#   ('descent', 'NN'),
#   ('clown', 'NN'),
#   ('princ', 'NN'),
#   ('crime', 'NN'),
#   ('know', 'VBP'),
#   ('incred', 'VBN'),
#   ('forgot', 'JJ'),
#   ('watch', 'NN'),
#   ('actor', 'NN'),
#   ('thought', 'VBD'),
#   ('watch', 'RB'),
#   ('documentari', 'JJ'),
#   ('par', 'JJ'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('joker', 'NN'),
#   ('sheer', 'NN'),
#   ('perform', 'NN'),
#   ('watch', 'NN'),
#   ('movi', 'NN')],
#  [('movi', 'NN'),
#   ('great', 'JJ'),
#   ('well', 'RB'),
#   ('made', 'VBN'),
#   ('movi', 'NN'),
#   ('tell', 'NN'),
#   ('stori', 'FW'),
#   ('fail', 'NN'),
#   ('comedian', 'NN'),
#   ('good', 'JJ'),
#   ('plot', 'NN'),
#   ('recommend', 'VB'),
#   ('small', 'JJ'),
#   ('child', 'NN')],
#  [('wouldnt', 'NN'),
#   ('chang', 'JJ'),
#   ('thing', 'NN'),
#   ('absolut', 'NN'),
#   ('perfectli', 'JJ'),
#   ('pace', 'NN'),
#   ('dialogu', 'NN'),
#   ('act', 'NN'),
#   ('want', 'VBP'),
#   ('sequel', 'NN')],
#  [('must', 'MD'),
#   ('chang', 'VB'),
#   ('text', 'JJ'),
#   ('ten', 'JJ'),
#   ('time', 'NN'),
#   ('realis', 'NN'),
#   ('movi', 'NN'),
#   ('masterpiec', 'NN'),
#   ('must', 'MD'),
#   ('silenc', 'VB'),
#   ('respectso', 'JJ'),
#   ('sit', 'NN'),
#   ('bow', 'NN'),
#   ('director', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('serv', 'NN'),
#   ('best', 'JJS'),
#   ('possibl', 'NN'),
#   ('waythank', 'NN'),
#   ('feel', 'NN'),
#   ('feltthank', 'VBD'),
#   ('touch', 'JJ'),
#   ('chello', 'NN'),
#   ('music', 'NN'),
#   ('thank', 'NN'),
#   ('soul', 'NN'),
#   ('danc', 'NN'),
#   ('moov', 'NN'),
#   ('thank', 'NN'),
#   ('amaz', 'NN'),
#   ('performancejoaquin', 'NN'),
#   ('deserv', 'NN'),
#   ('oscary', 'JJ'),
#   ('brilliant', 'NN')],
#  [('caus', 'NN'),
#   ('jokemarvel', 'NN'),
#   ('fanboy', 'NN'),
#   ('cri', 'NN'),
#   ('right', 'NN')],
#  [('see', 'VB'),
#   ('rate', 'NN'),
#   ('go', 'VB'),
#   ('wonder', 'NN'),
#   ('kind', 'NN'),
#   ('peopl', 'NN'),
#   ('would', 'MD'),
#   ('put', 'VB'),
#   ('movi', 'JJ'),
#   ('shame', 'NN'),
#   ('ultim', 'JJ'),
#   ('movi', 'NNS'),
#   ('need', 'VBP'),
#   ('review', 'VB'),
#   ('least', 'JJS'),
#   ('yanggang', 'JJ'),
#   ('humanityfirst', 'JJ'),
#   ('peopl', 'NN'),
#   ('come', 'VBP'),
#   ('amaz', 'NN'),
#   ('movi', 'NN')],
#  [('countri', 'NNS'),
#   ('make', 'VBP'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('care', 'NN'),
#   ('treatment', 'NN'),
#   ('unafford', 'JJ'),
#   ('poor', 'JJ'),
#   ('great', 'JJ'),
#   ('surpris', 'NN'),
#   ('mani', 'NN'),
#   ('blame', 'NN'),
#   ('poor', 'JJ'),
#   ('peopl', 'NN'),
#   ('unsuccess', 'JJ'),
#   ('therebi', 'NN'),
#   ('push', 'NN'),
#   ('edg', 'NN'),
#   ('societi', 'NN'),
#   ('add', 'VBP'),
#   ('second', 'JJ'),
#   ('amend', 'JJ'),
#   ('hand', 'NN'),
#   ('assault', 'NN'),
#   ('riffl', 'NN'),
#   ('anyon', 'NN'),
#   ('perfect', 'JJ'),
#   ('stormth', 'JJ'),
#   ('symbol', 'NN'),
#   ('scene', 'NN'),
#   ('opinion', 'NN'),
#   ('joker', 'NN'),
#   ('put', 'VBD'),
#   ('gun', 'JJ'),
#   ('head', 'NN'),
#   ('see', 'VB'),
#   ('face', 'NN'),
#   ('paint', 'NN'),
#   ('red', 'JJ'),
#   ('white', 'JJ'),
#   ('bluean', 'NN'),
#   ('import', 'NN'),
#   ('movi', 'NNS'),
#   ('hope', 'VBP'),
#   ('emphas', 'JJ'),
#   ('problem', 'NN'),
#   ('pave', 'VBP'),
#   ('way', 'NN'),
#   ('solut', 'NN')],
#  [('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('mayb', 'NN'),
#   ('best', 'RBS'),
#   ('live', 'JJ'),
#   ('actor', 'NN'),
#   ('today', 'NN'),
#   ('perform', 'VB')],
#  [('act', 'NN'),
#   ('scenographi', 'JJ'),
#   ('soundtrack', 'NN'),
#   ('storylin', 'NN'),
#   ('develop', 'VB'),
#   ('charact', 'JJ'),
#   ('everyth', 'NN'),
#   ('movi', 'NN'),
#   ('perfect', 'JJ'),
#   ('sincer', 'NN'),
#   ('consid', 'NN'),
#   ('best', 'JJS'),
#   ('movi', 'NN'),
#   ('ever', 'RB'),
#   ('made', 'VBD'),
#   ('know', 'JJ'),
#   ('huge', 'JJ'),
#   ('thing', 'NN'),
#   ('say', 'VBP'),
#   ('consid', 'NN'),
#   ('top', 'JJ'),
#   ('thank', 'NN'),
#   ('creat', 'NN'),
#   ('masterpiec', 'NN')],
#  [('chanc', 'NN'),
#   ('see', 'VBP'),
#   ('screen', 'JJ'),
#   ('joker', 'NN'),
#   ('venic', 'NN'),
#   ('film', 'NN'),
#   ('festiv', 'NN'),
#   ('last', 'JJ'),
#   ('week', 'NN'),
#   ('joker', 'NN'),
#   ('easili', 'VBP'),
#   ('one', 'CD'),
#   ('highlight', 'NN'),
#   ('festiv', 'NN'),
#   ('thank', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('breathtak', 'NN'),
#   ('perform', 'NN'),
#   ('todd', 'NN'),
#   ('phillip', 'NN'),
#   ('clever', 'NN'),
#   ('directingalthough', 'IN'),
#   ('movi', 'JJ'),
#   ('consist', 'NN'),
#   ('amaz', 'JJ'),
#   ('support', 'NN'),
#   ('cast', 'VBD'),
#   ('mostli', 'JJ'),
#   ('watch', 'NN'),
#   ('movi', 'NN'),
#   ('arthur', 'NN'),
#   ('joker', 'NN'),
#   ('lens', 'VBZ'),
#   ('arthur', 'JJ'),
#   ('present', 'JJ'),
#   ('everi', 'JJ'),
#   ('scene', 'NN'),
#   ('movi', 'NN'),
#   ('ala', 'NN'),
#   ('taxi', 'NN'),
#   ('drive', 'NN'),
#   ('movi', 'NN'),
#   ('clearli', 'NN'),
#   ('draw', 'NN'),
#   ('inspir', 'NN'),
#   ('scorses', 'VBZ'),
#   ('work', 'NN'),
#   ('notabl', 'RB'),
#   ('taxi', 'JJ'),
#   ('driver', 'NN'),
#   ('king', 'VBG'),
#   ('comedi', 'NN'),
#   ('there', 'RB'),
#   ('lot', 'VBZ'),
#   ('nod', 'JJ'),
#   ('easter', 'NN'),
#   ('egg', 'NN'),
#   ('fan', 'NN'),
#   ('two', 'CD'),
#   ('movi', 'NN'),
#   ('gotham', 'NN'),
#   ('citi', 'NN'),
#   ('see', 'VBP'),
#   ('movi', 'JJ'),
#   ('corrupt', 'JJ'),
#   ('version', 'NN'),
#   ('date', 'NN'),
#   ('expect', 'VBP'),
#   ('belov', 'NN'),
#   ('cape', 'NN'),
#   ('crusad', 'JJ'),
#   ('doesnt', 'NNS'),
#   ('exist', 'VBP'),
#   ('nightmarish', 'JJ'),
#   ('vision', 'NN'),
#   ('new', 'JJ'),
#   ('york', 'NN'),
#   ('corrupt', 'NN'),
#   ('crime', 'NN'),
#   ('chao', 'JJ'),
#   ('lead', 'NN'),
#   ('forc', 'NN'),
#   ('behind', 'IN'),
#   ('everyth', 'JJ'),
#   ('stori', 'NNS'),
#   ('take', 'VBP'),
#   ('clever', 'JJ'),
#   ('twist', 'NN'),
#   ('turn', 'VBP'),
#   ('leav', 'JJ'),
#   ('even', 'RB'),
#   ('hardcor', 'VBP'),
#   ('wellread', 'JJ'),
#   ('dc', 'NN'),
#   ('fan', 'NN'),
#   ('jaw', 'NN'),
#   ('floor', 'NN'),
#   ('wish', 'NN'),
#   ('could', 'MD'),
#   ('talk', 'VB'),
#   ('dont', 'NN'),
#   ('want', 'NN'),
#   ('go', 'VBP'),
#   ('spoiler', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('perform', 'VB'),
#   ('clown', 'JJ'),
#   ('princ', 'NN'),
#   ('crime', 'NN'),
#   ('there', 'RB'),
#   ('realli', 'RB'),
#   ('much', 'JJ'),
#   ('say', 'VBP'),
#   ('havent', 'JJ'),
#   ('read', 'JJ'),
#   ('alreadi', 'NN'),
#   ('phoenix', 'NN'),
#   ('liter', 'RBR'),
#   ('transform', 'JJ'),
#   ('role', 'NN'),
#   ('arthur', 'NN'),
#   ('fleck', 'NN'),
#   ('joker', 'NN'),
#   ('give', 'VBP'),
#   ('u', 'JJ'),
#   ('super', 'JJ'),
#   ('realist', 'NN'),
#   ('groundbreak', 'NN'),
#   ('perform', 'VB'),
#   ('even', 'RB'),
#   ('oscar', 'PRP'),
#   ('cant', 'VBP'),
#   ('snob', 'JJ'),
#   ('joker', 'NN'),
#   ('strong', 'JJ'),
#   ('contend', 'NN'),
#   ('best', 'JJS'),
#   ('picturethi', 'NN'),
#   ('movi', 'NN'),
#   ('must', 'MD'),
#   ('watch', 'VB'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('drama', 'NN'),
#   ('fan', 'NN'),
#   ('alik', 'JJ'),
#   ('deep', 'JJ'),
#   ('charact', 'NN'),
#   ('studi', 'JJ'),
#   ('mental', 'NN'),
#   ('ill', 'NN'),
#   ('man', 'NN'),
#   ('slowli', 'NN'),
#   ('sink', 'VBP'),
#   ('mad', 'JJ'),
#   ('shouldnt', 'NN'),
#   ('overlook', 'IN'),
#   ('anyoneoveral', 'JJ'),
#   ('movi', 'NN'),
#   ('get', 'NN'),
#   ('cant', 'JJ'),
#   ('wait', 'NN'),
#   ('see', 'VB'),
#   ('small', 'JJ'),
#   ('budget', 'NN'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('movi', 'NN'),
#   ('dc', 'NN'),
#   ('villain', 'NN'),
#   ('hero', 'NN')],
#  [('joker', 'NN'),
#   ('epic', 'NN'),
#   ('fantast', 'NN'),
#   ('charact', 'NN'),
#   ('studi', 'JJ'),
#   ('centr', 'NN'),
#   ('around', 'IN'),
#   ('popular', 'JJ'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('villain', 'NN'),
#   ('alltim', 'NN'),
#   ('craft', 'NN'),
#   ('stori', 'NNS'),
#   ('make', 'VBP'),
#   ('incarn', 'JJ'),
#   ('charact', 'NN'),
#   ('stand', 'VBP'),
#   ('beauti', 'NN'),
#   ('craft', 'NN'),
#   ('piec', 'NN'),
#   ('stun', 'NN'),
#   ('cinematographi', 'JJ'),
#   ('art', 'NN'),
#   ('direct', 'JJ'),
#   ('im', 'NN'),
#   ('fan', 'NN'),
#   ('chang', 'NN'),
#   ('appear', 'VBP'),
#   ('joker', 'NN'),
#   ('todd', 'NN'),
#   ('phillip', 'NN'),
#   ('fantast', 'JJ'),
#   ('job', 'NN'),
#   ('director', 'NN'),
#   ('writer', 'NN'),
#   ('chair', 'NN'),
#   ('phillip', 'NN'),
#   ('tackl', 'NN'),
#   ('certain', 'JJ'),
#   ('polit', 'JJ'),
#   ('social', 'JJ'),
#   ('issu', 'NN'),
#   ('spark', 'NN'),
#   ('convers', 'NNS'),
#   ('group', 'NN'),
#   ('full', 'JJ'),
#   ('peopl', 'NN'),
#   ('smarter', 'RBR'),
#   ('understood', 'JJ'),
#   ('messag', 'NN'),
#   ('come', 'VBN'),
#   ('across', 'IN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('one', 'CD'),
#   ('biggest', 'JJS'),
#   ('draw', 'NN'),
#   ('film', 'NN'),
#   ('praiseworthi', 'NN'),
#   ('perform', 'NN'),
#   ('dont', 'NN'),
#   ('realli', 'NN'),
#   ('care', 'NN'),
#   ('oscar', 'VBZ'),
#   ('award', 'RB'),
#   ('show', 'JJ'),
#   ('anymor', 'JJ'),
#   ('phoenix', 'NN'),
#   ('deserv', 'NN'),
#   ('accolad', 'VBD'),
#   ('come', 'JJ'),
#   ('way', 'NN'),
#   ('master', 'NN'),
#   ('haunt', 'NN'),
#   ('performanceon', 'JJ'),
#   ('thing', 'NN'),
#   ('must', 'MD'),
#   ('point', 'VB'),
#   ('unfair', 'JJ'),
#   ('compar', 'JJ'),
#   ('phoenix', 'NN'),
#   ('heath', 'NN'),
#   ('ledger', 'NN'),
#   ('perform', 'NN'),
#   ('dark', 'JJ'),
#   ('knight', 'NN'),
#   ('may', 'MD'),
#   ('play', 'VB'),
#   ('charact', 'VB'),
#   ('name', 'JJ'),
#   ('two', 'CD'),
#   ('drastic', 'JJ'),
#   ('differ', 'NNS'),
#   ('portray', 'VBP'),
#   ('perform', 'JJ'),
#   ('script', 'NN'),
#   ('unjust', 'JJ'),
#   ('compar', 'NN'),
#   ('worship', 'NN'),
#   ('fact', 'NN'),
#   ('given', 'VBN'),
#   ('two', 'CD'),
#   ('immens', 'NNS'),
#   ('perform', 'VBP'),
#   ('two', 'CD'),
#   ('differ', 'VBP'),
#   ('actor', 'NN')],
#  [('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('good', 'JJ'),
#   ('actor', 'NN'),
#   ('think', 'VBP'),
#   ('becom', 'IN'),
#   ('legend', 'JJ'),
#   ('nice', 'JJ'),
#   ('movi', 'NN'),
#   ('great', 'JJ'),
#   ('act', 'NN'),
#   ('great', 'JJ'),
#   ('actor', 'NN'),
#   ('unforgett', 'JJ'),
#   ('movi', 'NN')],
#  [('hype', 'NN'),
#   ('trailer', 'NN'),
#   ('kinda', 'NN'),
#   ('expect', 'VBP'),
#   ('disappoint', 'NN'),
#   ('dc', 'NN'),
#   ('khow', 'NN'),
#   ('well', 'RB'),
#   ('turn', 'VB'),
#   ('even', 'RB'),
#   ('better', 'RBR'),
#   ('trailer', 'NN'),
#   ('shown', 'VBN'),
#   ('im', 'JJ'),
#   ('grad', 'NN'),
#   ('act', 'NN'),
#   ('movi', 'RB'),
#   ('good', 'JJ'),
#   ('hat', 'WP'),
#   ('new', 'JJ'),
#   ('joker', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('deserv', 'NN'),
#   ('oscar', 'NN'),
#   ('act', 'NN'),
#   ('stori', 'FW'),
#   ('line', 'NN'),
#   ('still', 'RB'),
#   ('kinda', 'VB'),
#   ('classic', 'JJ'),
#   ('joker', 'NN'),
#   ('darker', 'NN'),
#   ('lot', 'NN'),
#   ('twist', 'NN'),
#   ('cant', 'NN'),
#   ('count', 'NN'),
#   ('mani', 'NN'),
#   ('time', 'NN'),
#   ('almost', 'RB'),
#   ('jump', 'JJ'),
#   ('sit', 'NN'),
#   ('supris', 'NN'),
#   ('excit', 'JJ'),
#   ('sooo', 'NN'),
#   ('mani', 'NN'),
#   ('dark', 'JJ'),
#   ('joke', 'NN'),
#   ('love', 'NN')],
#  [('noth', 'DT'),
#   ('say', 'VBP'),
#   ('neg', 'JJ'),
#   ('film', 'NN'),
#   ('movi', 'NN'),
#   ('show', 'NN'),
#   ('perfect', 'JJ'),
#   ('aspect', 'JJ'),
#   ('lead', 'NN'),
#   ('actor', 'NN'),
#   ('done', 'VBN'),
#   ('fabul', 'JJ'),
#   ('job', 'NN'),
#   ('never', 'RB'),
#   ('disappoint', 'NN'),
#   ('u', 'JJ'),
#   ('role', 'NN'),
#   ('joker', 'NN'),
#   ('perfectli', 'NN'),
#   ('act', 'NN')],
#  [('whole', 'JJ'),
#   ('year', 'NN'),
#   ('never', 'RB'),
#   ('watch', 'VBP'),
#   ('movi', 'NNS'),
#   ('play', 'VBP'),
#   ('emot', 'RB'),
#   ('quit', 'VBP'),
#   ('like', 'IN'),
#   ('film', 'NN'),
#   ('joker', 'NN'),
#   ('charact', 'NN'),
#   ('studi', 'VBP'),
#   ('one', 'CD'),
#   ('famou', 'NN'),
#   ('villain', 'NN'),
#   ('dc', 'JJ'),
#   ('comic', 'JJ'),
#   ('film', 'NN'),
#   ('expect', 'VBP'),
#   ('stori', 'NN'),
#   ('man', 'NN'),
#   ('mental', 'NN'),
#   ('ill', 'JJ'),
#   ('keep', 'VB'),
#   ('go', 'VB'),
#   ('extrem', 'JJ'),
#   ('side', 'NN'),
#   ('insan', 'NN'),
#   ('movi', 'NN'),
#   ('well', 'RB'),
#   ('joaquin', 'RB'),
#   ('phoenix', 'VB'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('perform', 'NN'),
#   ('year', 'NN'),
#   ('deserv', 'NN'),
#   ('oscar', 'NN'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('though', 'IN'),
#   ('small', 'JJ'),
#   ('role', 'NN'),
#   ('amaz', 'NN'),
#   ('perform', 'NN'),
#   ('well', 'RB'),
#   ('stori', 'RB'),
#   ('much', 'JJ'),
#   ('inspir', 'NN'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('differ', 'VBP'),
#   ('well', 'RB'),
#   ('much', 'JJ'),
#   ('watch', 'NN'),
#   ('movi', 'NN'),
#   ('person', 'NN'),
#   ('comic', 'JJ'),
#   ('fan', 'NN'),
#   ('must', 'MD'),
#   ('watch', 'VB'),
#   ('amaz', 'NN'),
#   ('movi', 'NN')],
#  [('amaz', 'RB'),
#   ('geniu', 'JJ'),
#   ('real', 'JJ'),
#   ('movi', 'NN'),
#   ('watch', 'NN')],
#  [('movi', 'NN'),
#   ('earn', 'NN'),
#   ('oscar', 'NN'),
#   ('best', 'JJS'),
#   ('actor', 'NN'),
#   ('concern', 'NN'),
#   ('movi', 'NNS'),
#   ('make', 'VBP'),
#   ('feel', 'NN'),
#   ('sorrow', 'NN'),
#   ('crimin', 'NN')],
#  [('best', 'JJS'),
#   ('movi', 'NN'),
#   ('year', 'NN'),
#   ('best', 'RB'),
#   ('joker', 'NN'),
#   ('ever', 'RB'),
#   ('seen', 'VBN'),
#   ('realist', 'NN')],
#  [('person', 'NN'),
#   ('love', 'VB'),
#   ('film', 'NN'),
#   ('let', 'NN'),
#   ('honest', 'VB'),
#   ('dont', 'NN'),
#   ('care', 'NN'),
#   ('think', 'NN'),
#   ('would', 'MD'),
#   ('dont', 'VB'),
#   ('even', 'RB'),
#   ('know', 'VBP'),
#   ('meno', 'RBS'),
#   ('want', 'VBP'),
#   ('know', 'JJ'),
#   ('youll', 'NN'),
#   ('like', 'IN'),
#   ('film', 'NN'),
#   ('look', 'VBP'),
#   ('sign', 'JJ'),
#   ('occasion', 'NN'),
#   ('hidden', 'JJ'),
#   ('deep', 'JJ'),
#   ('insid', 'NN'),
#   ('ocean', 'JJ'),
#   ('egocentr', 'JJ'),
#   ('opinion', 'NN'),
#   ('whether', 'IN'),
#   ('willth', 'NN'),
#   ('answer', 'NN'),
#   ('simpleif', 'NN'),
#   ('want', 'VBP'),
#   ('expect', 'JJ'),
#   ('semblanc', 'NN'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('movi', 'NN'),
#   ('there', 'RB'),
#   ('good', 'JJ'),
#   ('chanc', 'NN'),
#   ('youll', 'NN'),
#   ('disappoint', 'NN'),
#   ('doesnt', 'NN'),
#   ('attempt', 'NN'),
#   ('beth', 'VBZ'),
#   ('common', 'JJ'),
#   ('comparison', 'NN'),
#   ('like', 'IN'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('youll', 'NN'),
#   ('love', 'NN'),
#   ('oversimplifi', 'NN'),
#   ('yet', 'RB'),
#   ('astoundingli', 'JJ'),
#   ('accur', 'NN'),
#   ('true', 'JJ'),
#   ('your', 'PRP$'),
#   ('fan', 'NN'),
#   ('taxi', 'NN'),
#   ('driver', 'NN'),
#   ('similar', 'JJ'),
#   ('film', 'NN'),
#   ('youll', 'NN'),
#   ('right', 'NN'),
#   ('home', 'NN'),
#   ('laugh', 'IN'),
#   ('shouldnt', 'NN'),
#   ('along', 'IN'),
#   ('jokerth', 'NN'),
#   ('act', 'NN'),
#   ('outstand', 'VBP'),
#   ('across', 'IN'),
#   ('board', 'NN'),
#   ('cinematographi', 'NN'),
#   ('absolut', 'IN'),
#   ('fantast', 'JJ'),
#   ('everyth', 'NN'),
#   ('set', 'VBN'),
#   ('design', 'NN'),
#   ('edit', 'NN'),
#   ('add', 'VBP'),
#   ('fact', 'NN'),
#   ('anoth', 'DT'),
#   ('rare', 'JJ'),
#   ('classicinthewait', 'NN'),
#   ('film', 'NN'),
#   ('happen', 'VB'),
#   ('draw', 'VB'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('seri', 'NN')],
#  [('best', 'JJS'),
#   ('joker', 'NN'),
#   ('adapt', 'NN'),
#   ('ever', 'RB'),
#   ('everyth', 'VBZ'),
#   ('dark', 'JJ'),
#   ('youd', 'NN'),
#   ('want', 'VBP'),
#   ('charact', 'NN'),
#   ('smile', 'NN'),
#   ('throughout', 'IN'),
#   ('well', 'RB'),
#   ('worth', 'JJ'),
#   ('everi', 'NN'),
#   ('penni', 'NN'),
#   ('perfect', 'JJ'),
#   ('amount', 'NN'),
#   ('mad', 'NN'),
#   ('incred', 'VBD'),
#   ('soundtrack', 'NN'),
#   ('dont', 'NN'),
#   ('even', 'RB'),
#   ('complaint', 'VB'),
#   ('satisfi', 'NN'),
#   ('absolut', 'IN'),
#   ('love', 'NN'),
#   ('profound', 'NN'),
#   ('joaquin', 'NN'),
#   ('phoenix', 'NN'),
#   ('health', 'NN'),
#   ('ledger', 'NN'),
#   ('best', 'JJS'),
#   ('joker', 'NN'),
#   ('well', 'RB'),
#   ('realli', 'VBZ'),
#   ('hope', 'NN'),
#   ('get', 'VB'),
#   ('nomin', 'JJ'),
#   ('oscar', 'NN'),
#   ('id', 'NN'),
#   ('danc', 'NN'),
#   ('wild', 'JJ'),
#   ('jig', 'NN'),
#   ('also', 'RB'),
#   ('th', 'VBZ'),
#   ('review', 'NN'),
#   ('realli', 'NN'),
#   ('cool', 'NN')],
#  [],
#  [('movi', 'NN'),
#   ('get', 'NN'),
#   ('lot', 'NN'),
#   ('prais', 'NN'),
#   ('film', 'NN'),
#   ('deserv', 'NN'),
#   ('imo', 'NN'),
#   ('better', 'RBR'),
#   ('endgam', 'NN'),
#   ('dark', 'NN'),
#   ('knight', 'VBD')],
#  [('phoenix', 'NN'),
#   ('best', 'JJS'),
#   ('joker', 'NN'),
#   ('ever', 'RB'),
#   ('deserv', 'VBZ'),
#   ('oscarthi', 'JJ'),
#   ('best', 'JJS'),
#   ('movi', 'NN'),
#   ('year', 'NN')]]

# %%
from collections import Counter
pos_counts=[]
lines=0
for j in pos:
  lines=lines+1
  counts = Counter(tag for word,tag in j)             #Number of POS in each sentence.
  pos_counts.append(str(lines)+" "+str(counts))
pos_counts
# Out:
# ["1 Counter({'NN': 52, 'JJ': 19, 'RB': 6, 'VBP': 6, 'VB': 3, 'NNS': 3, 'VBN': 3, 'VBD': 2, 'JJS': 2, 'MD': 2, 'DT': 1, 'WDT': 1, 'VBZ': 1, 'IN': 1})",
#  "2 Counter({'NN': 27, 'JJ': 9, 'RB': 3, 'VBP': 3, 'NNS': 1, 'IN': 1, 'JJS': 1, 'VB': 1, 'VBN': 1})",
#  "3 Counter({'NN': 20, 'JJ': 7, 'VBP': 4, 'IN': 3, 'VBD': 1, 'CD': 1, 'RBR': 1, 'RB': 1, 'VB': 1})",
#  "4 Counter({'NN': 20, 'JJ': 10, 'JJS': 3, 'VBP': 2, 'NNS': 1, 'CD': 1, 'VBG': 1})",
#  "5 Counter({'NN': 24, 'JJ': 12, 'VBP': 3, 'NNS': 2, 'IN': 1, 'JJS': 1, 'VBN': 1, 'RB': 1, 'JJR': 1})",
#  "6 Counter({'NN': 27, 'JJ': 8, 'VBD': 4, 'VB': 3, 'IN': 3, 'FW': 1, 'VBP': 1, 'RB': 1})",
#  "7 Counter({'NN': 37, 'JJ': 17, 'VB': 5, 'RB': 4, 'VBD': 3, 'VBP': 3, 'FW': 1, 'JJS': 1, 'IN': 1, 'VBG': 1, 'RBS': 1})",
#  "8 Counter({'NN': 17, 'VB': 4, 'JJ': 4, 'VBP': 2, 'MD': 1, 'VBN': 1, 'RB': 1, 'IN': 1})",
#  "9 Counter({'NN': 73, 'JJ': 31, 'RB': 8, 'VBP': 6, 'JJS': 4, 'IN': 3, 'NNS': 3, 'VBN': 2, 'VB': 2, 'VBZ': 2, 'MD': 1, 'VBD': 1, 'VBG': 1, 'WP': 1})",
#  "10 Counter({'NN': 33, 'JJ': 13, 'VB': 4, 'VBP': 1, 'RB': 1, 'VBD': 1, 'RP': 1, 'JJS': 1, 'VBZ': 1})",
#  '11 Counter()',
#  "12 Counter({'NN': 32, 'JJ': 16, 'VBP': 7, 'NNS': 4, 'RB': 3, 'VBD': 2, 'IN': 1, 'MD': 1, 'VB': 1, 'JJS': 1})",
#  "13 Counter({'NN': 9, 'JJ': 2, 'VBP': 2, 'NNS': 1})",
#  "14 Counter({'NN': 7, 'VB': 1, 'JJ': 1})",
#  "15 Counter({'NN': 57, 'JJ': 29, 'VBD': 8, 'VBP': 6, 'RB': 3, 'MD': 3, 'VB': 3, 'NNS': 2, 'NNP': 2, 'VBZ': 1, 'VBN': 1, 'IN': 1})",
#  "16 Counter({'NN': 33, 'JJ': 10, 'VBP': 3, 'NNS': 2, 'IN': 2, 'VBZ': 1, 'JJR': 1, 'RB': 1})",
#  "17 Counter({'NN': 32, 'JJ': 7, 'VBP': 5, 'NNS': 5, 'CD': 3, 'VB': 2, 'RB': 2, 'VBD': 2, 'JJS': 1})",
#  "18 Counter({'NN': 28, 'JJ': 12, 'VB': 3, 'VBP': 3, 'MD': 2, 'VBZ': 1, 'RB': 1, 'VBD': 1, 'IN': 1, 'NNS': 1})",
#  "19 Counter({'NN': 57, 'JJ': 22, 'VBP': 8, 'VB': 6, 'IN': 4, 'RB': 4, 'NNS': 3, 'VBN': 2, 'JJR': 2, 'PRP': 2, 'VBZ': 2, 'VBD': 1, 'JJS': 1, 'MD': 1})",
#  "20 Counter({'NN': 30, 'JJ': 4, 'DT': 1, 'VBG': 1, 'VBP': 1})",
#  "21 Counter({'NN': 26, 'JJ': 9, 'VBD': 4, 'VBP': 3, 'RB': 2, 'IN': 1, 'FW': 1, 'CD': 1, 'JJS': 1})",
#  "22 Counter({'NN': 15, 'JJ': 5, 'VB': 2, 'VBP': 2, 'MD': 1, 'NNS': 1, 'IN': 1, 'VBZ': 1, 'JJR': 1})",
#  "23 Counter({'NN': 61, 'JJ': 16, 'VBP': 5, 'RB': 4, 'IN': 4, 'JJS': 4, 'NNS': 3, 'VB': 3, 'VBZ': 2, 'WP': 2, 'VBD': 2, 'CD': 2, 'MD': 2, 'VBN': 1, 'NNP': 1, 'RBR': 1, 'RP': 1})",
#  "24 Counter({'NN': 14, 'JJS': 4, 'JJ': 2, 'VBP': 2, 'JJR': 1, 'VB': 1, 'CD': 1})",
#  "25 Counter({'NN': 103, 'JJ': 40, 'RB': 11, 'VBP': 10, 'VBD': 8, 'IN': 7, 'VB': 4, 'VBN': 4, 'CD': 3, 'MD': 2, 'JJS': 2, 'RP': 2, 'NNS': 2, 'JJR': 1, 'RBR': 1})",
#  "26 Counter({'NN': 7, 'CD': 2, 'JJS': 2, 'VBZ': 1, 'JJ': 1, 'RB': 1})",
#  "27 Counter({'NN': 21, 'JJ': 6, 'RB': 3, 'IN': 3, 'VBD': 3, 'VBN': 1, 'VB': 1, 'FW': 1, 'CC': 1})",
#  "28 Counter({'NN': 20, 'JJ': 6, 'VBD': 3, 'CD': 3, 'VBP': 2, 'JJS': 1, 'VBN': 1, 'RB': 1, 'DT': 1})",
#  "29 Counter({'NN': 194, 'JJ': 76, 'VB': 24, 'VBP': 16, 'IN': 14, 'RB': 12, 'MD': 12, 'VBD': 6, 'NNS': 4, 'CD': 4, 'VBZ': 2, 'RBR': 1, 'EX': 1, 'FW': 1, 'JJR': 1, 'DT': 1})",
#  "30 Counter({'NN': 19, 'JJ': 7, 'RB': 1, 'VBZ': 1, 'VB': 1, 'JJS': 1, 'VBP': 1})",
#  "31 Counter({'NN': 9, 'JJ': 2, 'VBP': 1, 'CD': 1, 'VBN': 1, 'VB': 1})",
#  "32 Counter({'NN': 4, 'JJ': 2, 'NNS': 1, 'VBP': 1})",
#  "33 Counter({'NN': 21, 'JJ': 4, 'VBP': 2, 'RB': 2, 'VB': 2, 'VBD': 1, 'WDT': 1})",
#  "34 Counter({'NN': 8, 'JJ': 1})",
#  "35 Counter({'NN': 9, 'MD': 1, 'VB': 1, 'JJ': 1})",
#  "36 Counter({'NN': 33, 'JJ': 10, 'NNS': 3, 'IN': 3, 'VB': 2, 'VBP': 2, 'VBD': 2, 'VBN': 2, 'JJS': 1, 'RB': 1, 'RBR': 1})",
#  "37 Counter({'NN': 18, 'JJ': 7, 'VBP': 3, 'IN': 1, 'NNS': 1, 'RB': 1, 'DT': 1, 'VBN': 1, 'CD': 1})",
#  "38 Counter({'NN': 29, 'JJ': 3, 'VBN': 3, 'IN': 2, 'VB': 2, 'RB': 1, 'MD': 1, 'VBD': 1})",
#  "39 Counter({'NN': 4, 'JJS': 1, 'VBP': 1})",
#  "40 Counter({'NN': 11, 'JJ': 3, 'VBD': 2, 'RB': 1, 'WP': 1, 'VBZ': 1, 'RBR': 1, 'NNS': 1, 'VBP': 1})",
#  "41 Counter({'NN': 87, 'JJ': 30, 'VBD': 7, 'RB': 6, 'VBP': 5, 'VB': 4, 'IN': 4, 'VBN': 3, 'CD': 2, 'JJS': 2, 'MD': 2, 'NNS': 2})",
#  "42 Counter({'NN': 14, 'JJ': 5, 'VB': 1, 'RB': 1, 'VBN': 1})",
#  "43 Counter({'NN': 92, 'JJ': 36, 'VBP': 9, 'RB': 6, 'VBN': 6, 'IN': 6, 'VBD': 3, 'NNS': 2, 'CD': 2, 'VB': 1, 'JJS': 1})",
#  '44 Counter()',
#  "45 Counter({'NN': 16, 'FW': 1, 'JJ': 1, 'VBZ': 1, 'JJR': 1})",
#  "46 Counter({'NN': 29, 'JJ': 11, 'VB': 5, 'VBP': 4, 'RB': 4, 'VBD': 2, 'NNS': 2, 'DT': 1, 'CD': 1, 'MD': 1, 'VBN': 1})",
#  "47 Counter({'NN': 18, 'JJ': 3, 'VBD': 2, 'VBP': 2, 'VBZ': 1})",
#  "48 Counter({'NN': 15, 'JJ': 7, 'JJS': 4, 'RBS': 3, 'VBD': 1, 'NNS': 1, 'VBP': 1, 'IN': 1, 'MD': 1, 'VB': 1})",
#  '49 Counter()',
#  "50 Counter({'NN': 45, 'JJ': 14, 'VBP': 9, 'VB': 9, 'RB': 7, 'IN': 5, 'NNS': 4, 'MD': 4, 'JJS': 3, 'CD': 1, 'VBD': 1, 'PRP$': 1, 'VBZ': 1})",
#  "51 Counter({'NN': 11, 'CD': 1, 'JJ': 1})",
#  "52 Counter({'NN': 28, 'JJ': 13, 'VBP': 4, 'RB': 4, 'WP$': 1, 'VBD': 1, 'IN': 1})",
#  "53 Counter({'NN': 38, 'JJ': 9, 'VBP': 4, 'RB': 3, 'VB': 3, 'VBZ': 2, 'VBD': 2, 'VBN': 1, 'NNS': 1, 'MD': 1})",
#  '54 Counter()',
#  "55 Counter({'NN': 17, 'JJ': 7, 'VBP': 2, 'IN': 2, 'VB': 2, 'NNS': 1, 'RB': 1, 'VBN': 1, 'DT': 1, 'FW': 1, 'MD': 1})",
#  "56 Counter({'NN': 10, 'JJ': 1, 'IN': 1})",
#  "57 Counter({'NN': 6, 'RB': 1, 'VB': 1})",
#  "58 Counter({'NN': 56, 'JJ': 12, 'VBP': 7, 'IN': 3, 'NNS': 3, 'RB': 3, 'VB': 3, 'VBN': 2, 'DT': 1, 'VBD': 1, 'CD': 1, 'MD': 1})",
#  "59 Counter({'NN': 8, 'VB': 3, 'JJ': 2, 'MD': 1})",
#  "60 Counter({'NN': 109, 'JJ': 45, 'RB': 14, 'VBP': 12, 'VB': 12, 'IN': 9, 'MD': 4, 'NNS': 4, 'VBN': 3, 'VBD': 3, 'JJS': 3, 'CD': 2, 'PRP': 1, 'RBR': 1, 'EX': 1, 'DT': 1, 'WDT': 1, 'VBZ': 1})",
#  "61 Counter({'NN': 10, 'VB': 3, 'RB': 2, 'VBP': 1, 'JJ': 1})",
#  "62 Counter({'NN': 11, 'JJ': 3, 'NNS': 3, 'VBD': 2, 'VBP': 2, 'RB': 2, 'VBN': 1, 'CC': 1})",
#  "63 Counter({'NN': 6, 'JJ': 4, 'JJS': 2, 'IN': 1, 'VB': 1, 'JJR': 1, 'CD': 1})",
#  "64 Counter({'NN': 5, 'JJ': 3, 'VBN': 1, 'RB': 1})",
#  "65 Counter({'NN': 5, 'JJS': 1, 'VBP': 1})",
#  "66 Counter({'NN': 178, 'JJ': 82, 'RB': 24, 'VBP': 21, 'VB': 18, 'IN': 12, 'VBD': 8, 'NNS': 6, 'VBZ': 6, 'VBN': 4, 'MD': 4, 'CD': 3, 'JJR': 2, 'EX': 1, 'WP': 1, 'RP': 1, 'CC': 1, 'FW': 1, 'JJS': 1, 'VBG': 1})",
#  "67 Counter({'NN': 26, 'JJ': 14, 'VBD': 3, 'IN': 3, 'MD': 2, 'VB': 2, 'VBP': 2, 'NNS': 1, 'RB': 1})",
#  "68 Counter({'NN': 7, 'JJ': 2, 'RB': 1, 'VBN': 1, 'IN': 1})",
#  "69 Counter({'NN': 5, 'VBZ': 1, 'VBP': 1})",
#  "70 Counter({'NN': 34, 'JJ': 11, 'VBD': 2, 'JJS': 2, 'IN': 1, 'NNS': 1, 'CD': 1, 'VB': 1, 'VBN': 1})",
#  '71 Counter()',
#  "72 Counter({'NN': 6, 'VB': 1, 'JJ': 1})",
#  "73 Counter({'NN': 21, 'JJ': 13, 'VBP': 6, 'RB': 4, 'VB': 2, 'NNS': 1, 'VBN': 1, 'VBZ': 1})",
#  "74 Counter({'NN': 11, 'JJ': 2, 'CD': 1, 'JJS': 1, 'VBD': 1})",
#  '75 Counter()',
#  "76 Counter({'NN': 5, 'JJ': 3, 'VBP': 1, 'RB': 1, 'JJR': 1})",
#  "77 Counter({'NN': 22, 'JJ': 7, 'RB': 3, 'MD': 2, 'VBN': 2, 'VBP': 1, 'IN': 1, 'VB': 1})",
#  "78 Counter({'NN': 23, 'JJ': 6, 'VB': 4, 'MD': 2, 'VBP': 2, 'NNS': 1, 'VBN': 1, 'VBD': 1, 'RB': 1})",
#  "79 Counter({'NN': 7, 'JJ': 3, 'RB': 1, 'VBN': 1, 'FW': 1, 'VB': 1})",
#  "80 Counter({'NN': 7, 'JJ': 2, 'VBP': 1})",
#  "81 Counter({'NN': 24, 'JJ': 5, 'MD': 2, 'VB': 2, 'JJS': 1, 'VBD': 1})",
#  "82 Counter({'NN': 5})",
#  "83 Counter({'NN': 8, 'VB': 4, 'JJ': 4, 'VBP': 2, 'MD': 1, 'NNS': 1, 'JJS': 1})",
#  "84 Counter({'NN': 27, 'JJ': 14, 'VBP': 4, 'NNS': 2, 'VBD': 1, 'VB': 1})",
#  "85 Counter({'NN': 5, 'RBS': 1, 'JJ': 1, 'VB': 1})",
#  "86 Counter({'NN': 13, 'JJ': 6, 'VB': 1, 'JJS': 1, 'RB': 1, 'VBD': 1, 'VBP': 1})",
#  "87 Counter({'NN': 94, 'JJ': 38, 'VBP': 13, 'RB': 6, 'VB': 5, 'IN': 3, 'VBZ': 3, 'CD': 2, 'NNS': 2, 'MD': 2, 'VBD': 1, 'VBG': 1, 'RBR': 1, 'PRP': 1, 'JJS': 1})",
#  "88 Counter({'NN': 57, 'JJ': 23, 'VBP': 6, 'NNS': 4, 'CD': 4, 'VB': 3, 'IN': 2, 'VBN': 2, 'MD': 2, 'RBR': 1, 'JJS': 1, 'VBZ': 1, 'RB': 1, 'VBD': 1})",
#  "89 Counter({'NN': 7, 'JJ': 6, 'VBP': 1, 'IN': 1})",
#  "90 Counter({'NN': 30, 'JJ': 7, 'RB': 5, 'VB': 2, 'VBP': 1, 'RBR': 1, 'VBN': 1, 'WP': 1, 'FW': 1})",
#  "91 Counter({'NN': 11, 'JJ': 5, 'DT': 1, 'VBP': 1, 'VBN': 1, 'RB': 1})",
#  "92 Counter({'NN': 30, 'JJ': 9, 'RB': 7, 'VBP': 6, 'VB': 4, 'IN': 3, 'CD': 2, 'NNS': 1, 'JJS': 1, 'FW': 1, 'MD': 1})",
#  "93 Counter({'JJ': 2, 'NN': 2, 'RB': 1})",
#  "94 Counter({'NN': 8, 'JJS': 1, 'NNS': 1, 'VBP': 1})",
#  "95 Counter({'NN': 4, 'RB': 2, 'JJS': 1, 'VBN': 1})",
#  "96 Counter({'NN': 49, 'JJ': 16, 'IN': 7, 'VBP': 6, 'VB': 5, 'RB': 3, 'MD': 1, 'RBS': 1, 'VBZ': 1, 'PRP$': 1, 'VBN': 1, 'DT': 1})",
#  "97 Counter({'NN': 27, 'RB': 5, 'JJ': 5, 'VBZ': 3, 'JJS': 2, 'IN': 2, 'VB': 2, 'VBP': 1, 'VBD': 1})",
#  '98 Counter()',
#  "99 Counter({'NN': 9, 'RBR': 1, 'VBD': 1})",
#  "100 Counter({'NN': 4, 'JJS': 2, 'RB': 1, 'VBZ': 1, 'JJ': 1})"]

# %%
import os       #importing os to set environment variable
def install_java():
  # !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null      #install openjdk
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"     #set environment variable
  # !java -version       #check java version
install_java()
# Out:
# openjdk version "11.0.6" 2020-01-14
# OpenJDK Runtime Environment (build 11.0.6+10-post-Ubuntu-1ubuntu118.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.6+10-post-Ubuntu-1ubuntu118.04.1, mixed mode, sharing)

# %%
# !pip install stanfordnlp
# import stanfordnlp

# %%
# stanfordnlp.download('en', force=True)

# %%
from zipfile import ZipFile
with ZipFile('/stanford-parser-full-2015-04-20.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/stanfordparser')

# %%
# os.environ["CORENLP_HOME"] = "/temp/stanford-corenlp-full-2018-10-05"
# from stanfordnlp.server import CoreNLPClient

# # example text
# print('---')
# print('input text')
# print('')

# text = "Chris Manning is a nice person. Chris wrote a simple sentence. He also gives oranges to people."

# print(text)

# # set up the client
# print('---')
# print('starting up Java Stanford CoreNLP Server...')

# # set up the client
# with CoreNLPClient(annotators=['tokenize','ssplit','pos','lemma','ner','parse','depparse','coref'], timeout=60000, memory='16G') as client:
#     # submit the request to the server
#     ann = client.annotate(text)

#     # get the first sentence
#     sentence = ann.sentence[0]

#     # get the dependency parse of the first sentence
#     print('---')
#     print('dependency parse of first sentence')
#     dependency_parse = sentence.basicDependencies
#     print(dependency_parse)
 
#     # get the constituency parse of the first sentence
#     print('---')
#     print('constituency parse of first sentence')
#     constituency_parse = sentence.parseTree
#     print(constituency_parse)

# %%
from IPython.display import display
#display(result[0])
text = "Chris Manning is a nice person. Chris wrote a simple sentence. He also gives oranges to people."
from nltk.parse.stanford import StanfordParser
scp = StanfordParser(path_to_jar='/stanfordparser/stanford-parser-full-2015-04-20/stanford-parser.jar',
                     path_to_models_jar='/stanfordparser/stanford-parser-full-2015-04-20/stanford-parser-3.5.2-models.jar')
#number=0
#for text in lemmatized:
 # number=number+1
#  print('Constituency tree for sentence-'+str(number))
result = list(scp.raw_parse(text))
print(result[0])
# Out:
# (ROOT
#   (S
#     (S
#       (NP (NNP Chris) (NNP Manning))
#       (VP
#         (VBZ is)
#         (NP
#           (NP (DT a) (JJ nice))
#           (SBAR
#             (S
#               (NP (NN person) (. .) (NNP Chris))
#               (VP (VBD wrote) (NP (DT a) (JJ simple) (NN sentence)))))))
#       (. .))
#     (NP (PRP He))
#     (VP
#       (ADVP (RB also))
#       (VBZ gives)
#       (NP (NNS oranges))
#       (PP (TO to) (NP (NNS people))))
#     (. .)))

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**
